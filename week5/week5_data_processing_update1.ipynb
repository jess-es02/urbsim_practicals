# %% [markdown]
# ### CASA0002
#
# # Urban Simulation
# ***
# ## Working with real world data
#
# Mateo Neira
# ***
#
# Working with real world data comes with its own set of challenges. In this practical we will go over downloading and processing the public TFL multi-rail demand data set for London, which can be found [here](http://crowding.data.tfl.gov.uk).
#
# We will be using the data from the [NUMBAT project](http://crowding.data.tfl.gov.uk/NUMBAT/Intro_to_NUMBAT.pdf) -A comprehensive multi-rail demand data set for London. the NUMBAT dataset provides statistics on usage and travel patterns on TfL railway services. It is the most comprehensive multi-rail demand data set available for London.

# %% [markdown]
# ### TFL Origin Destination data
# ***
#
# We will be using the 2019 data set (as the 2020 dataset coincides with lockdown measures). The data TFL provides represents the travel demand on a typical autumn weekday (Monday-Thursday), Friday, Saturday, and Sunday at all stations and lines of the London Underground, London Overground, Docklands Light Railway, TfL Rail / Elizabeth Line (crossrail) and London Trams.
#
# ---
# ### Map of the network we will be constructing
#
# ![img](https://tfl.gov.uk/cdn/static/cms/images/london-rail-and-tube-services-map.gif)

# %% [markdown]
# ### Data Processing
#
# We need to perform the following steps to get the data we need in the right format for to run the analysis required for the final assesment:
#
#
# 1. Download raw data
#     * Get flow data from TFL
#     * Get geometries of the london rail & tube network from OSM
# 2. Preprocess the data
#     * Data wrangling of flow data from TFL
#     * Transform geometry of london rail & tube network into a graph
# 3. Merge TFL data and london underground shapefile
#     * Calculate flow data to input as weights in london network graph
#     * Calculate distances between stations to create file to be used in the spatial interaction model
#
# ---
# _The raw data has already been provided for you in data /data folder. You can still explore the data directly from the links provided. In the case of the London rail & tube network geometries, these have been extracted from OSM._

# %% [markdown]
# ### Data Wrangling of passenger flows
#
# We will be focusing only on the data that covers Monday-Thursday.
#
# The first file we need is the [NBT19_Definitions.xlsx](http://crowding.data.tfl.gov.uk/NUMBAT/NUMBAT%202019/NBT19_Definitions.xlsx) file that contains important information on what  different codes mean.
#
# The rest of the files relate to the OD matrix for the different lines organized by timebands which can be found here:
#
# * [NBT19MTT2b_od_DLR_tb_wf.csv](http://crowding.data.tfl.gov.uk/NUMBAT/NUMBAT%202019/NBT19_OD_data/NBT19MTT2b_od__DLR_tb_wf.csv)
# * [NBT19MTT2b_od__EZL_tb_wf.csv](http://crowding.data.tfl.gov.uk/NUMBAT/NUMBAT%202019/NBT19_OD_data/NBT19MTT2b_od__EZL_tb_wf.csv)
# * [NBT19MTT2b_od__LO_tb_wf.csv](http://crowding.data.tfl.gov.uk/NUMBAT/NUMBAT%202019/NBT19_OD_data/NBT19MTT2b_od__LO_tb_wf.csv)
# * [NBT19MTT2b_od__LU_tb_wf.csv](http://crowding.data.tfl.gov.uk/NUMBAT/NUMBAT%202019/NBT19_OD_data/NBT19MTT2b_od__LU_tb_wf.csv)
#
# _*note that the MTT code in the file name refers to Monday to Thursday data as specified in the definitions file_

# %%
# we will import all the necessary libraries
import pandas as pd
import numpy as np
import geopandas as gpd
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import json
import re
from shapely.geometry import Point, LineString #this library is for manipulating geometric objects, and it is what geopandas uses to store geometries
from scipy.spatial import distance

# %%
#tlf provides passenger flow data for each network separately
#we need to create a list of all the different files we need
files = ['NBT19MTT2b_od__DLR_tb_wf.csv', 
         'NBT19MTT2b_od__EZL_tb_wf.csv', 
         'NBT19MTT2b_od__LO_tb_wf.csv', 
         'NBT19MTT2b_od__LU_tb_wf.csv']

#create an empty list to store dataframes for each file
dfs = []

#iterate through our files list, read the file and append to our dataframe list
for file in files:
    dfs.append(pd.read_csv('data/' + file))
    
#merge all dataframes
london_OD = pd.concat(dfs, ignore_index=True)

# %%
#take a look at our data
london_OD.head()
# Out:
#    mode_mnlc_o  mode_mnlc_d       2        3        4        5        6  \
# 0          504          523   8.033   16.430   24.563   28.555   13.023
# 1          504          533  30.719   40.105   61.571   57.881   15.573
# 2          504          538   5.941   17.238   37.493   43.158   33.890
# 3          504          559   5.795   26.397   27.285   24.065   15.213
# 4          504          573  77.786  113.750  143.938  387.562  165.776
#
#         7 mode   1   8
# 0   2.263  DLR NaN NaN
# 1   0.317  DLR NaN NaN
# 2  10.429  DLR NaN NaN
# 3   8.508  DLR NaN NaN
# 4  65.283  DLR NaN NaN

# %% [markdown]
# #### Understanding our data
#
# If we read the information on the **Numbat Project** which as linked previously we can see that the data covers 15-minute periods. The specific datasets we are using are the O/D by network which registers number of trips between Origin and Destination station by time band.
#
# ---
# * mode_mnlc_o: code of origin station
# * mode_mnlc_d: code of destionation station
# * \[1,2,...,7,8\]: number of passengers in respective timeband
# * mode: type of network (London Undeground, London Overgroud, DRL, ...)
#
#
# Since we are only interested in home-to-work trips, we will only keep the data pertaining to the morning peak (7am - 10am). Again, if we look at the definition file we can see that this is timeband 3.
#
# Additionally, we need to map the station codes to station names, we will be using the definition file for this.

# %% [markdown]
# ### Get the mnlc codes
#
# We will use the **NBT19_Definitions.xlsx** file to get the codes to match station names.
#
# ```python
# pd.read_excel()
# ```
#
# The function requires the **openpyxl** library to work. this can be installed using pip or conda.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\jessi\anaconda3\envs\urbsim\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\jessi\anaconda3\envs\urbsim\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
definition_df = pd.read_excel('data/NBT19_Definitions.xlsx', 'Stations')
definition_df.head()
# Out:
#     MNLC  MASC                  StationName  TFL?
# 0  500.0  ACTu                   Acton Town  True
# 1  501.0  BARu                     Barbican  True
# 2  502.0  ALDu                      Aldgate  True
# 3  503.0  ALEu                 Aldgate East  True
# 4  504.0  STId  Stratford International DLR  True

# %%
#we will drop any missing values from our dataframe
definition_df.dropna(inplace=True)

#transform mnlc codes from floats to int
definition_df.MNLC = definition_df.MNLC.astype(int)
definition_df.head()
# Out:
#    MNLC  MASC                  StationName  TFL?
# 0   500  ACTu                   Acton Town  True
# 1   501  BARu                     Barbican  True
# 2   502  ALDu                      Aldgate  True
# 3   503  ALEu                 Aldgate East  True
# 4   504  STId  Stratford International DLR  True

# %%
#add the station names
london_OD['station_origin'] = london_OD['mode_mnlc_o'].apply(lambda x: definition_df[definition_df.MNLC==x]['StationName'].values[0])
london_OD['station_destination'] = london_OD['mode_mnlc_d'].apply(lambda x: definition_df[definition_df.MNLC==x]['StationName'].values[0])
london_OD.head()
# Out:
#    mode_mnlc_o  mode_mnlc_d       2        3        4        5        6  \
# 0          504          523   8.033   16.430   24.563   28.555   13.023
# 1          504          533  30.719   40.105   61.571   57.881   15.573
# 2          504          538   5.941   17.238   37.493   43.158   33.890
# 3          504          559   5.795   26.397   27.285   24.065   15.213
# 4          504          573  77.786  113.750  143.938  387.562  165.776
#
#         7 mode   1   8               station_origin  station_destination
# 0   2.263  DLR NaN NaN  Stratford International DLR        King George V
# 1   0.317  DLR NaN NaN  Stratford International DLR  London City Airport
# 2  10.429  DLR NaN NaN  Stratford International DLR         Pontoon Dock
# 3   8.508  DLR NaN NaN  Stratford International DLR      West Silvertown
# 4  65.283  DLR NaN NaN  Stratford International DLR     Woolwich Arsenal

# %%
# we will only keep passenger flows for the timeband we are interested in
london_OD_AMpeak = london_OD[['station_origin', 'station_destination', '3']].copy()
london_OD_AMpeak.head()
# Out:
#                 station_origin  station_destination        3
# 0  Stratford International DLR        King George V   16.430
# 1  Stratford International DLR  London City Airport   40.105
# 2  Stratford International DLR         Pontoon Dock   17.238
# 3  Stratford International DLR      West Silvertown   26.397
# 4  Stratford International DLR     Woolwich Arsenal  113.750

# %%
#rename column
london_OD_AMpeak.rename({'3':'flows'}, axis=1, inplace=True)

#since the flows are averages the are stored as floats.
#for our analysis we will turn the into ints
london_OD_AMpeak.flows = london_OD_AMpeak.flows.astype(int)
london_OD_AMpeak.head()
# Out:
#                 station_origin  station_destination  flows
# 0  Stratford International DLR        King George V     16
# 1  Stratford International DLR  London City Airport     40
# 2  Stratford International DLR         Pontoon Dock     17
# 3  Stratford International DLR      West Silvertown     26
# 4  Stratford International DLR     Woolwich Arsenal    113

# %% [markdown]
# Let's get all the station names

# %%
station_origin = list(london_OD_AMpeak.station_origin.values)
station_destination = list(london_OD_AMpeak.station_destination.values)
all_stations = list(set(station_origin + station_destination))
all_stations = sorted(all_stations, key=str.lower)

# %%
all_stations
# Out:
# ['Abbey Road',
#  'Acton Central',
#  'Acton Main Line',
#  'Acton Town',
#  'Aldgate',
#  'Aldgate East',
#  'All Saints',
#  'Alperton',
#  'Amersham',
#  'Anerley',
#  'Angel',
#  'Archway',
#  'Arnos Grove',
#  'Arsenal',
#  'Baker Street',
#  'Balham LU',
#  'Bank and Monument',
#  'Barbican',
#  'Barking',
#  'Barkingside',
#  'Barons Court',
#  'Battersea Park',
#  'Bayswater',
#  'Beckton',
#  'Beckton Park',
#  'Becontree',
#  'Belsize Park',
#  'Bermondsey',
#  'Bethnal Green LO',
#  'Bethnal Green LU',
#  'Blackfriars LU',
#  'Blackhorse Road',
#  'Blackwall',
#  'Bond Street',
#  'Borough',
#  'Boston Manor',
#  'Bounds Green',
#  'Bow Church',
#  'Bow Road',
#  'Brent Cross',
#  'Brentwood',
#  'Brixton LU',
#  'Brockley',
#  'Bromley-by-Bow',
#  'Brondesbury',
#  'Brondesbury Park',
#  'Bruce Grove',
#  'Buckhurst Hill',
#  'Burnt Oak',
#  'Bush Hill Park',
#  'Bushey',
#  'Caledonian Road',
#  'Caledonian Road & Barnsbury',
#  'Cambridge Heath',
#  'Camden Road',
#  'Camden Town',
#  'Canada Water',
#  'Canary Wharf DLR',
#  'Canary Wharf LU',
#  'Canning Town',
#  'Cannon Street LU',
#  'Canonbury',
#  'Canons Park',
#  'Carpenders Park',
#  'Chadwell Heath',
#  'Chalfont & Latimer',
#  'Chalk Farm',
#  'Chancery Lane',
#  'Charing Cross LU',
#  'Chesham',
#  'Cheshunt',
#  'Chigwell',
#  'Chingford',
#  'Chiswick Park',
#  'Chorleywood',
#  'Clapham Common',
#  'Clapham High Street',
#  'Clapham Junction',
#  'Clapham North',
#  'Clapham South',
#  'Clapton',
#  'Cockfosters',
#  'Colindale',
#  'Colliers Wood',
#  'Covent Garden',
#  'Crossharbour',
#  'Crouch Hill',
#  'Croxley',
#  'Crystal Palace',
#  'Custom House',
#  'Cutty Sark',
#  'Cyprus',
#  'Dagenham East',
#  'Dagenham Heathway',
#  'Dalston Junction',
#  'Dalston Kingsland',
#  'Debden',
#  'Denmark Hill',
#  'Deptford Bridge',
#  'Devons Road',
#  'Dollis Hill',
#  'Ealing Broadway',
#  'Ealing Common',
#  "Earl's Court",
#  'East Acton',
#  'East Finchley',
#  'East Ham',
#  'East India',
#  'East Putney',
#  'Eastcote',
#  'Edgware',
#  'Edgware Road (Bak)',
#  'Edgware Road (DIS)',
#  'Edmonton Green',
#  'Elephant & Castle LU',
#  'Elm Park',
#  'Elverson Road',
#  'Embankment',
#  'Emerson Park',
#  'Enfield Town',
#  'Epping',
#  'Euston LU',
#  'Euston NR',
#  'Euston Square',
#  'Fairlop',
#  'Farringdon',
#  'Finchley Central',
#  'Finchley Road',
#  'Finchley Road & Frognal',
#  'Finsbury Park LU',
#  'Forest Gate',
#  'Forest Hill',
#  'Fulham Broadway',
#  'Gallions Reach',
#  'Gants Hill',
#  'Gidea Park',
#  'Gloucester Road',
#  'Golders Green',
#  'Goldhawk Road',
#  'Goodge Street',
#  'Goodmayes',
#  'Gospel Oak',
#  'Grange Hill',
#  'Great Portland Street',
#  'Green Park',
#  'Greenford',
#  'Greenwich',
#  'Gunnersbury',
#  'Hackney Central',
#  'Hackney Downs',
#  'Hackney Wick',
#  'Haggerston',
#  'Hainault',
#  'Hammersmith (DIS)',
#  'Hammersmith (H&C)',
#  'Hampstead',
#  'Hampstead Heath',
#  'Hanger Lane',
#  'Hanwell',
#  'Harlesden',
#  'Harold Wood',
#  'Harringay Green Lanes',
#  'Harrow & Wealdstone',
#  'Harrow-on-the-Hill',
#  'Hatch End',
#  'Hatton Cross',
#  'Hayes & Harlington',
#  'Headstone Lane',
#  'Heathrow Terminal 4 EL',
#  'Heathrow Terminal 4 LU',
#  'Heathrow Terminal 5 LU',
#  'Heathrow Terminals 123 LU',
#  'Heathrow Terminals 2 & 3 EL',
#  'Hendon Central',
#  'Heron Quays',
#  'High Barnet',
#  'High Street Kensington',
#  'Highams Park',
#  'Highbury & Islington',
#  'Highgate',
#  'Hillingdon',
#  'Holborn',
#  'Holland Park',
#  'Holloway Road',
#  'Homerton',
#  'Honor Oak Park',
#  'Hornchurch',
#  'Hounslow Central',
#  'Hounslow East',
#  'Hounslow West',
#  'Hoxton',
#  'Hyde Park Corner',
#  'Ickenham',
#  'Ilford',
#  'Imperial Wharf',
#  'Island Gardens',
#  'Kennington',
#  'Kensal Green',
#  'Kensal Rise',
#  'Kensington (Olympia)',
#  'Kentish Town',
#  'Kentish Town West',
#  'Kenton',
#  'Kew Gardens',
#  'Kilburn',
#  'Kilburn High Road',
#  'Kilburn Park',
#  'King George V',
#  "King's Cross St. Pancras",
#  'Kingsbury',
#  'Knightsbridge',
#  'Ladbroke Grove',
#  'Lambeth North',
#  'Lancaster Gate',
#  'Langdon Park',
#  'Latimer Road',
#  'Leicester Square',
#  'Lewisham DLR',
#  'Leyton',
#  'Leyton Midland Road',
#  'Leytonstone',
#  'Leytonstone High Road',
#  'Limehouse DLR',
#  'Liverpool Street LU',
#  'Liverpool Street NR',
#  'London Bridge LU',
#  'London City Airport',
#  'London Fields',
#  'Loughton',
#  'Maida Vale',
#  'Manor House',
#  'Manor Park',
#  'Mansion House',
#  'Marble Arch',
#  'Maryland',
#  'Marylebone LU',
#  'Mile End',
#  'Mill Hill East',
#  'Moor Park',
#  'Moorgate',
#  'Morden',
#  'Mornington Crescent',
#  'Mudchute',
#  'Neasden',
#  'New Cross',
#  'New Cross Gate',
#  'Newbury Park',
#  'North Acton',
#  'North Ealing',
#  'North Greenwich',
#  'North Harrow',
#  'North Wembley',
#  'Northfields',
#  'Northolt',
#  'Northwick Park',
#  'Northwood',
#  'Northwood Hills',
#  'Norwood Junction',
#  'Notting Hill Gate',
#  'Oakwood',
#  'Old Street',
#  'Osterley',
#  'Oval',
#  'Oxford Circus',
#  'Paddington NR',
#  'Paddington TfL',
#  'Park Royal',
#  'Parsons Green',
#  'Peckham Rye',
#  'Penge West',
#  'Perivale',
#  'Piccadilly Circus',
#  'Pimlico',
#  'Pinner',
#  'Plaistow',
#  'Pontoon Dock',
#  'Poplar',
#  'Preston Road',
#  'Prince Regent',
#  'Pudding Mill Lane',
#  'Putney Bridge',
#  "Queen's Park",
#  'Queens Road Peckham',
#  'Queensbury',
#  'Queensway',
#  'Ravenscourt Park',
#  'Rayners Lane',
#  'Rectory Road',
#  'Redbridge',
#  "Regent's Park",
#  'Richmond',
#  'Rickmansworth',
#  'Roding Valley',
#  'Romford',
#  'Rotherhithe',
#  'Royal Albert',
#  'Royal Oak',
#  'Royal Victoria',
#  'Ruislip',
#  'Ruislip Gardens',
#  'Ruislip Manor',
#  'Russell Square',
#  'Seven Kings',
#  'Seven Sisters',
#  'Shadwell DLR',
#  'Shadwell LO',
#  'Shenfield',
#  "Shepherd's Bush LU",
#  "Shepherd's Bush Market",
#  "Shepherd's Bush NR",
#  'Shoreditch High Street',
#  'Silver Street',
#  'Sloane Square',
#  'Snaresbrook',
#  'South Acton',
#  'South Ealing',
#  'South Hampstead',
#  'South Harrow',
#  'South Kensington',
#  'South Kenton',
#  'South Quay',
#  'South Ruislip',
#  'South Tottenham',
#  'South Wimbledon',
#  'South Woodford',
#  'Southall',
#  'Southbury',
#  'Southfields',
#  'Southgate',
#  'Southwark',
#  'St James Street',
#  "St. James's Park",
#  "St. John's Wood",
#  "St. Paul's",
#  'Stamford Brook',
#  'Stamford Hill',
#  'Stanmore',
#  'Star Lane',
#  'Stepney Green',
#  'Stockwell',
#  'Stoke Newington',
#  'Stonebridge Park',
#  'Stratford',
#  'Stratford High Street',
#  'Stratford International DLR',
#  'Sudbury Hill',
#  'Sudbury Town',
#  'Surrey Quays',
#  'Swiss Cottage',
#  'Sydenham',
#  'Temple',
#  'Theobalds Grove',
#  'Theydon Bois',
#  'Tooting Bec',
#  'Tooting Broadway',
#  'Tottenham Court Road',
#  'Tottenham Hale LU',
#  'Totteridge & Whetstone',
#  'Tower Gateway',
#  'Tower Hill',
#  'Tufnell Park',
#  'Turkey Street',
#  'Turnham Green',
#  'Turnpike Lane',
#  'Upminster',
#  'Upminster Bridge',
#  'Upney',
#  'Upper Holloway',
#  'Upton Park',
#  'Uxbridge',
#  'Vauxhall LU',
#  'Victoria LU',
#  'Walthamstow Central',
#  "Walthamstow Queen's Road",
#  'Wandsworth Road',
#  'Wanstead',
#  'Wanstead Park',
#  'Wapping',
#  'Warren Street',
#  'Warwick Avenue',
#  'Waterloo LU',
#  'Watford',
#  'Watford High Street',
#  'Watford Junction',
#  'Wembley Central',
#  'Wembley Park',
#  'West Acton',
#  'West Brompton',
#  'West Croydon NR',
#  'West Ealing',
#  'West Finchley',
#  'West Ham',
#  'West Hampstead LO',
#  'West Hampstead LU',
#  'West Harrow',
#  'West India Quay',
#  'West Kensington',
#  'West Ruislip',
#  'West Silvertown',
#  'Westbourne Park',
#  'Westferry',
#  'Westminster',
#  'White City',
#  'White Hart Lane',
#  'Whitechapel',
#  'Willesden Green',
#  'Willesden Junction',
#  'Wimbledon',
#  'Wimbledon Park',
#  'Wood Green',
#  'Wood Lane',
#  'Wood Street',
#  'Woodford',
#  'Woodgrange Park',
#  'Woodside Park',
#  'Woolwich Arsenal']

# %%
#check the duplicative station names
pattern = r'.*(?:LU|LO|NR|TfL|DLR|\(.*\)).*'
matches = [station for station in all_stations if re.search(pattern, station)]
#print duplicative station names
print('Duplicative station names:')
for station in sorted(matches): print(f'- {station}')
# Out:
# Duplicative station names:
# - Balham LU
# - Bethnal Green LO
# - Bethnal Green LU
# - Blackfriars LU
# - Brixton LU
# - Canary Wharf DLR
# - Canary Wharf LU
# - Cannon Street LU
# - Charing Cross LU
# - Edgware Road (Bak)
# - Edgware Road (DIS)
# - Elephant & Castle LU
# - Euston LU
# - Euston NR
# - Finsbury Park LU
# - Hammersmith (DIS)
# - Hammersmith (H&C)
# - Heathrow Terminal 4 LU
# - Heathrow Terminal 5 LU
# - Heathrow Terminals 123 LU
# - Kensington (Olympia)
# - Lewisham DLR
# - Limehouse DLR
# - Liverpool Street LU
# - Liverpool Street NR
# - London Bridge LU
# - Marylebone LU
# - Paddington NR
# - Paddington TfL
# - Shadwell DLR
# - Shadwell LO
# - Shepherd's Bush LU
# - Shepherd's Bush NR
# - Stratford International DLR
# - Tottenham Hale LU
# - Vauxhall LU
# - Victoria LU
# - Waterloo LU
# - West Croydon NR
# - West Hampstead LO
# - West Hampstead LU

# %% [markdown]
# We will need to clean this, as we want all stations that are the same summed. for example Hammersmith (DIS) and Hammersmith (H&C) are the same station. so we want these flows to be summed into one one just called Hammersmith. For this we will simplify all names by:
# * removing all text in between ()
# * removing LU, LO, NR, Tfl,  DLR
#
# We will use [RegEx](https://en.wikipedia.org/wiki/Regular_expression) to match and replace station names.

# %%
london_OD_AMpeak['station_origin']= london_OD_AMpeak.station_origin.apply(lambda x: 
                                      re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)
                                     )
london_OD_AMpeak['station_destination']=london_OD_AMpeak.station_destination.apply(lambda x: 
                                      re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)
                                     )
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jessi\AppData\Local\Temp\ipykernel_44796\3679263834.py:2: SyntaxWarning: invalid escape sequence '\s'
#   re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)
# C:\Users\jessi\AppData\Local\Temp\ipykernel_44796\3679263834.py:5: SyntaxWarning: invalid escape sequence '\s'
#   re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)

# %% [markdown]
# now we will sum the flows of stations with the same origin-destination name

# %%
#group by origin and destination station and sum the flows
london_OD_AMpeak = london_OD_AMpeak.groupby(['station_origin', 'station_destination'], as_index=False).sum()

# %%
london_OD_AMpeak
# Out:
#          station_origin station_destination  flows
# 0            Abbey Road   Bank and Monument      0
# 1            Abbey Road             Beckton      1
# 2            Abbey Road           Blackwall      3
# 3            Abbey Road        Canary Wharf      1
# 4            Abbey Road        Canning Town     37
# ...                 ...                 ...    ...
# 61523  Woolwich Arsenal       Tower Gateway    127
# 61524  Woolwich Arsenal            West Ham    608
# 61525  Woolwich Arsenal     West India Quay      6
# 61526  Woolwich Arsenal     West Silvertown     81
# 61527  Woolwich Arsenal           Westferry     76
#
# [61528 rows x 3 columns]

# %% [markdown]
# #### Does our data make sense?
#
# * Do the stations with least and most in and out flows make sense?
# * What type of data distribtion would we expect?

# %%
#let's sanity check and see the highest and lowest flows in and out flows
outflows = london_OD_AMpeak.groupby('station_origin', as_index=False).sum()

# %%
outflows.sort_values('flows',ascending=False).head(10)
# Out:
#                station_origin  \
# 371                  Waterloo
# 333                 Stratford
# 362                  Victoria
# 219             London Bridge
# 218          Liverpool Street
# 16          Bank and Monument
# 203  King's Cross St. Pancras
# 55               Canada Water
# 125             Finsbury Park
# 258                Paddington
#
#                                    station_destination  flows
# 371  Acton TownAldgateAldgate EastAlpertonAmershamA...  67372
# 333  Abbey RoadActon CentralActon TownAldgateAldgat...  59311
# 362  Acton TownAldgateAldgate EastAlpertonAmershamA...  37517
# 219  Acton TownAldgateAldgate EastAlpertonAmershamA...  32597
# 218  Acton TownAldgateAldgate EastAlpertonAmershamA...  31473
# 16   Abbey RoadActon TownAldgateAldgate EastAll Sai...  29494
# 203  Acton TownAldgateAldgate EastAlpertonAmershamA...  28307
# 55   Acton CentralActon TownAlpertonAmershamAnerley...  27026
# 125  Acton TownAldgateAldgate EastAlpertonAmershamA...  24735
# 258  Acton Main LineActon TownAldgateAldgate EastAl...  24071

# %%
outflows.sort_values('flows',ascending=False).tail(10)
# Out:
#                   station_origin  \
# 52               Cambridge Heath
# 24                  Beckton Park
# 186             Hyde Park Corner
# 298                    Shenfield
# 307              South Hampstead
# 167  Heathrow Terminals 2 & 3 EL
# 49                        Bushey
# 68                      Cheshunt
# 385              West India Quay
# 21                Battersea Park
#
#                                    station_destination  flows
# 52   Bethnal GreenBruce GroveBush Hill ParkCaledoni...    328
# 24   Bank and MonumentBecktonBlackwallBow ChurchCan...    293
# 186  Acton TownAldgateAldgate EastAlpertonAmershamA...    259
# 298  BrentwoodChadwell HeathForest GateGidea ParkGo...    248
# 307  Acton CentralBusheyCarpenders ParkEustonGunner...    248
# 167  Ealing BroadwayHanwellHayes & HarlingtonHeathr...    242
# 49   Acton CentralBarkingBrondesburyCarpenders Park...    238
# 68   BarkingBethnal GreenBruce GroveCambridge Heath...    171
# 385  All SaintsBank and MonumentBecktonBlackwallBow...    162
# 21   BrockleyCanada WaterClapham High StreetDalston...      0

# %%
#let's sanity check and see the highest and lowest flows in and out flows
inflows = london_OD_AMpeak.groupby('station_destination', as_index=False).sum()

# %%
inflows.sort_values('flows',ascending=False).head(10)
# Out:
#           station_destination  \
# 16          Bank and Monument
# 218          Liverpool Street
# 56               Canary Wharf
# 333                 Stratford
# 257             Oxford Circus
# 203  King's Cross St. Pancras
# 362                  Victoria
# 219             London Bridge
# 140                Green Park
# 121                Farringdon
#
#                                         station_origin  flows
# 16   Abbey RoadActon TownAldgateAldgate EastAll Sai...  78549
# 218  Acton TownAldgateAldgate EastAlpertonAmershamA...  61122
# 56   Abbey RoadActon TownAldgateAldgate EastAll Sai...  58772
# 333  Abbey RoadActon CentralActon TownAldgateAldgat...  55954
# 257  Acton TownAldgateAldgate EastAlpertonAmershamA...  44368
# 203  Acton TownAldgateAldgate EastAlpertonAmershamA...  33330
# 362  Acton TownAldgateAldgate EastAlpertonAmershamA...  33251
# 219  Acton TownAldgateAldgate EastAlpertonAmershamA...  29930
# 140  Acton TownAldgateAldgate EastAlpertonAmershamA...  26754
# 121  Acton TownAldgateAldgate EastAlpertonAmershamA...  25592

# %%
inflows.sort_values('flows',ascending=False).tail(10)
# Out:
#     station_destination                                     station_origin  \
# 343        Theydon Bois  Aldgate EastAngelBank and MonumentBarbicanBark...
# 159           Hatch End  Acton CentralBusheyCamden RoadCarpenders ParkC...
# 381       West Finchley  AldgateAldgate EastAngelArchwayBaker StreetBal...
# 24         Beckton Park  Bank and MonumentBecktonBlackwallBow ChurchCan...
# 285       Roding Valley  Aldgate EastAngelBank and MonumentBarbicanBark...
# 138         Grange Hill  Aldgate EastAngelBaker StreetBalhamBank and Mo...
# 153             Hanwell  Ealing BroadwayHayes & HarlingtonHeathrow Term...
# 2       Acton Main Line  Ealing BroadwayHayes & HarlingtonPaddingtonSou...
# 115        Emerson Park                                   RomfordUpminster
# 21       Battersea Park  BrockleyCanada WaterClapham High StreetDalston...
#
#      flows
# 343     98
# 159     93
# 381     91
# 24      88
# 285     84
# 138     76
# 153     72
# 2       70
# 115     42
# 21       0

# %%
#let's plot this as a histogram
bin_size=100
fig, ax = plt.subplots(2,1,figsize=(12,10))
ax[0].hist(outflows['flows'], bins=int(outflows['flows'].max()/bin_size))
ax[0].set_xlabel('London am peak outflows', fontsize = 15)
ax[0].set_ylabel("Count", fontsize= 15)
ax[0].grid(True)

ax[1].hist(inflows['flows'], bins=int(inflows['flows'].max()/bin_size))
ax[1].set_xlabel('London am peak inflows', fontsize = 15)
ax[1].set_ylabel("Count", fontsize= 15)
ax[1].grid(True)
plt.show()

# %% [markdown]
# ### Load London Underground shapefile data
#
# Now that we have our Origin-Destination data, we need to construct a network representing the london rail & tube services. This is a bit more tricky, because we need both a topologically correct network, plus clean geometries so we can calculate distances to use as weights.
#
# The raw data we are using comes from OSM and it's inherently messy. We have two seperate files, one for stations and another for the lines.
#
# **These are the types of errors we will encounter:**
#
# ![errors](img/errors.png)

# %%
#read in the data using geopandas
stations = gpd.read_file('data/tfl_stations.json')
lines = gpd.read_file('data/tfl_lines.json')

# %%
#project data to British National Grid
#we do this so we can work in meters
stations = stations.to_crs(epsg = 27700)
lines = lines.to_crs(epsg = 27700)

# %% [markdown]
# ### Stations file

# %%
stations.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           529 non-null    object
#  1   name         529 non-null    object
#  2   nlc_id       518 non-null    object
#  3   lines        529 non-null    object
#  4   cartography  529 non-null    object
#  5   altmodeid    16 non-null     object
#  6   alt_id       337 non-null    object
#  7   altmodeid2   2 non-null      object
#  8   zone         529 non-null    object
#  9   geometry     529 non-null    geometry
# dtypes: geometry(1), object(9)
# memory usage: 41.5+ KB

# %%
stations.head()
# Out:
#             id          name nlc_id  \
# 0  940GZZLUACT    Acton Town   0500
# 1  940GZZLUACY       Archway   0508
# 2  940GZZLUADE  Aldgate East   0503
# 3  940GZZLUAGL         Angel   0507
# 4  940GZZLUALD       Aldgate   0502
#
#                                                lines  \
# 0  [ { "name": "District" }, { "name": "Piccadill...
# 1    [ { "name": "Northern", "nightopened": 2016 } ]
# 2  [ { "name": "District" }, { "name": "Hammersmi...
# 3  [ { "name": "Northern" }, { "name": "Crossrail...
# 4  [ { "name": "Circle" }, { "name": "Metropolita...
#
#                       cartography altmodeid alt_id altmodeid2 zone  \
# 0                { "labelX": 30 }      None      1       None    3
# 1               { "labelX": -30 }      None      8       None  2/3
# 2                { "labelX": 30 }      None      3       None    1
# 3  { "labelX": 1, "labelY": -35 }      None      7       None    1
# 4  { "labelX": 25, "labelY": 20 }      None      2       None    1
#
#                         geometry
# 0  POINT (519483.347 179591.968)
# 1   POINT (529380.63 186814.054)
# 2  POINT (533885.038 181342.159)
# 3  POINT (531460.461 183134.266)
# 4  POINT (533621.756 181218.291)

# %%
stations.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Clean station names
#
# We have multiple points representing one station (for example Paddington has seperate points for different entrances). We will simplify this by using RegEx make the names consistent.
#
# Once we have cleaned the names we can set the coordinate of these stations to the mean values of the coordinates of all the stations with the same name.

# %%
#get all station names
station_names = {row.id: row['name'] for i, row in stations.iterrows()}

# %%
#clean station names (same code as above)
for k, v in station_names.items():
    if k == 'none':
        continue
    cleaned_name = re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', v)
    
    #note that bank and monument are enconded as one station in our TFL data, so we will do the same
    if cleaned_name in ['Bank', 'Monument']:
        cleaned_name = 'Bank and Monument'
    station_names[k] = cleaned_name
    
stations['name'] = stations['id'].apply(lambda x: station_names[x])
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jessi\AppData\Local\Temp\ipykernel_44796\205507679.py:5: SyntaxWarning: invalid escape sequence '\s'
#   cleaned_name = re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', v)

# %%
## we will plot all the stations with multiple points to check there are no errors
fig, ax = plt.subplots(figsize = (30,30))
ax.set_aspect("equal")
ax.axis('off')
ax.margins(0.2)
color = iter(cm.rainbow(np.linspace(0, 1, 29)))
stations.plot(ax=ax, color='grey', markersize=30)
for i, group in stations.groupby('name'):
    if len(group)>1:
        group.plot(ax=ax, color = next(color), markersize=50)
plt.show()

# %% [markdown]
# **Change position of station to mean of all station with the same name**

# %%
#get position of stations as mean of x, y of stations

#create empty dict to store list of coordinates
pos = {}

#iterate through the stations
for i, station in stations.iterrows():
    xy = station.geometry.coords[0]
    
    #if station already in dict add coordinate to coordinate list
    if station['name'] in pos.keys():
        pos[station['name']].extend([xy])
    #if station is not in the dict add station to dict and set first coordinate in list
    else:
        pos[station['name']] = [xy]

#iterate through our dict and replace coordinate list with mean value
for k, v in pos.items():
    #we set axis to 0 to make sure to take mean of x and y coordinates
    pos[k] = np.mean(v, axis=0)

# %%
#set new geometry
stations['geometry'] = stations['name'].apply(lambda x: Point(pos[x]))

# %%
#check plot to make sure there are no errors
stations.plot(markersize=2)
# Out:
# <Axes: >

# %% [markdown]
# ### Lines file

# %%
lines.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        701 non-null    object
#  1   lines     701 non-null    object
#  2   geometry  701 non-null    geometry
# dtypes: geometry(1), object(2)
# memory usage: 16.6+ KB

# %%
lines.head()
# Out:
#                id                                              lines  \
# 0  LeaValleyLine1  [ { "name": "London Overground", "opened": 201...
# 1  LeaValleyLine2  [ { "name": "London Overground", "opened": 201...
# 2  LeaValleyLine3  [ { "name": "London Overground", "opened": 201...
# 3  LeaValleyLine4  [ { "name": "London Overground", "opened": 201...
# 4  LeaValleyLine5  [ { "name": "London Overground", "opened": 201...
#
#                                             geometry
# 0  LINESTRING (534724.174 182339.718, 534745.702 ...
# 1  LINESTRING (534824.633 183292.947, 534819.116 ...
# 2  LINESTRING (534781.329 184262.444, 534783.973 ...
# 3  LINESTRING (534528.505 185136.296, 534524.111 ...
# 4  LINESTRING (533994.782 186186.712, 533977.905 ...

# %%
lines.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Get all line names
#
# We can see from our lines geodataframe that one geometry can represent multiple lines (for example one for the circle line and another for hammersmith and city) that go between the same stations.
#
# Let's work each line seperately to make cleaning and checking the data easier.

# %%
#get all line types as a list and subset geoms by lines
line_names  = lines.lines.apply(lambda x: [x['name'] for x in json.loads(x)] )
line_names = list(set([item for sublist in line_names for item in sublist]))
line_names
# Out:
# ['Emirates Air Line',
#  'Crossrail',
#  'Victoria',
#  'District',
#  'Metropolitan',
#  'East London',
#  'Northern',
#  'Crossrail 2',
#  'Circle',
#  'Tramlink',
#  'Bakerloo',
#  'London Overground',
#  'Piccadilly',
#  'Waterloo & City',
#  'Hammersmith & City',
#  'Central',
#  'Jubilee',
#  'TfL Rail',
#  'DLR',
#  'Thameslink 6tph line']

# %%
# check the data for each line
for line in line_names:
    #I'm removing thameslink 6tph line because there are not corresponding stations in station file
    if line == 'Thameslink 6tph line':
        continue
    fig, ax = plt.subplots(figsize = (7,7))
    fig.suptitle(f'line: {line}')
    ax.set_aspect("equal")
    ax.axis('off')
    ax.margins(0.1)
    temp_lines = lines[lines.lines.str.contains(line)]
    base = temp_lines.plot(ax=ax)
    temp_stations = stations[stations.lines.str.contains(line)]
    temp_stations.plot(ax=base, markersize=20)
    plt.show()

# %%
#We can see that east london line is incomplete
#digging into this however we notice that it's because east london is actually part of the overground
#merge East London line and London Overground since they are one line
lines.lines = lines.lines.str.replace('East London', 'London Overground')
stations.lines = stations.lines.str.replace('East London', 'London Overground')

# %%
#Our TFL data doesn't include tramlink, emirates air lines, and crossrail is still in construction (except not really)
#exclude the lines that we are not going to use
excluded_lines = ['Thameslink 6tph line', 'East London', 'Crossrail 2', 'Emirates Air Line', 'Crossrail', 'Tramlink']

# %% [markdown]
# ## Create seperate graphs for each line and then join
#
# Since we don't have properly constructed line geometries because:
# * there are discontinuities in the line geometries
# * a line between two stations can actually be composed of more than one geometry
#
# We will construct geometric graphs (meaning graphs just from the line geometries where nodes are coordinates that define the line geometry). It's easy to fix the discontinuities in this manner because the can be thought of as nodes with degree = 1 that have another node with degree = 1 within a threshold distance.
#
# Once we have these discontinuties fixed we can use these geometric graphs to construct proper geometries between stations by taking the shortest paths within these networks starting from the node closest to the origin station and ending in the node closest to the destination station. The shortest path will then be a list of coordinates that define the line geometry between the two stations.

# %%
#create an empty dict to hold our geometric graphs
geometric_graphs = {}

#iterate through each line individually
for line_name in line_names:
    #skip lines that we won't be using
    if line_name in excluded_lines :
        continue
    print(line_name)
    
    #subset our line and station files for the ones the belong to a specific line
    temp_lines = lines[lines.lines.str.contains(line_name)]
    temp_stations = stations[stations.lines.str.contains(line_name)]
    
    #create empty graph
    G= nx.Graph()
    
    #iterate through our line geometries
    for i, line in temp_lines.iterrows():
        #get list of coordinates that define our line
        _l = list(line.geometry.coords)

        #add coordinates as edges
        G.add_edges_from(list(zip(_l,_l[1:])))
    
    #remove any self loops
    G.remove_edges_from(nx.selfloop_edges(G))
    
    #the position of the node is the name of the node
    #let's extract this to plot our graph
    pos = {n: n for n in G.nodes()}
    
    # get degree one nodes
    D = nx.degree(G)
    k1 = [node for node,degree in D if degree==1]
    #let's plot our graph and all degree one nodes
    nx.draw(G, pos=pos, node_size=0.5, node_color='grey')
    nx.draw_networkx_nodes(G, pos=pos, nodelist=k1, node_color='red', node_size=8)
    plt.show()
    
    #get distance between all points of 1-degree, this will be a matrix
    dist = distance.cdist(k1, k1)
    
    #add edges between points that are close
    for j in range(dist.shape[0]-1):
        temp = dist[j][j+1:]
        #get index of closest node
        i_min = np.argmin(temp)
        if dist[j][i_min+j+1]<50:
            G.add_edge(k1[j],k1[i_min+j+1])
    
    #recalculate degree
    D = nx.degree(G)
    k1 = [node for node,degree in D if degree==1]
    #plot new graph
    nx.draw(G, pos=pos, node_size=0.5, node_color='grey')
    nx.draw_networkx_nodes(G, pos=pos, nodelist=k1, node_color='red', node_size=8)
    plt.show()
    print(nx.number_connected_components(G))
    #store graph in dictionary
    geometric_graphs[line_name] = G
# Out:
# Victoria
# 1
# District
# 1
# Metropolitan
# 1
# Northern
# 1
# Circle
# 1
# Bakerloo
# 1
# London Overground
# 3
# Piccadilly
# 1
# Waterloo & City
# 1
# Hammersmith & City
# 1
# Central
# 1
# Jubilee
# 1
# TfL Rail
# 1
# DLR
# 1

# %% [markdown]
# Now that we have these geometric graphs we can create our final graph by using the data in the lines attribute in our lines geodataframe that contains origin and destination station. We can then use our geometric graph and find the shortest route to create our line geometries and find the length of the lines.
#
# We will store this information in a dataframe that we can use to create our final graph

# %%
#create a dataframe with all geometries from all valid lines
#this list will contain a dictionary for each edge in our graph that contains
# node pairs, line name, and a geometry (this is just for quick visualization purposes and will be replaced by true geometry)
edge_list = []
def _has_ids(k):
    #helper function to check if line contains id of start and end station
    if ('start_sid' in k.keys()) and ('end_sid' in k.keys()):
        return True
    else:
        return False

#iterate through each line seperately 
for line_name in line_names:
    if line_name in excluded_lines :
        continue
        
    #subset lines and stations
    temp_lines = lines[lines.lines.str.contains(line_name)]
    temp_stations = stations[stations.lines.str.contains(line_name)]
    
    #for each line in our subset dataframe get each origin and destination pair
    for i, line in temp_lines.iterrows():
        for k in json.loads(line.lines):
            if k['name'] == line_name:
                if _has_ids(k):
                    #get start and end station ids
                    start_id = k['start_sid']
                    end_id = k['end_sid']

                    #get info of start and end station
                    start_station = temp_stations[(temp_stations.id == start_id) | (temp_stations.altmodeid == start_id)].values
                    end_station = temp_stations[(temp_stations.id == end_id) | (temp_stations.altmodeid == end_id)].values
                    
                    #if no matching station exist, let's just take the starting and ending coordinate of the line for now
                    if len(start_station) >= 1 and len(end_station) >=1:
                        s_geom = start_station[0][-1].coords[0]
                        e_geom = end_station[0][-1].coords[0]
                        edge_list.append({
                            'line_name': line_name,
                            'start_id': start_id,
                            'end_id': end_id,
                            'geometry': LineString([s_geom, e_geom])
                        })

# %%
#turn our dictionary list into a geopandas df to quickly plot and sanity check our work
edge_gdf = gpd.GeoDataFrame(edge_list)
edge_gdf.crs = lines.crs
edge_gdf.plot()
edge_gdf.head()
# Out:
#   line_name     start_id       end_id  \
# 0  Victoria  940GZZLUBXN  940GZZLUSKW
# 1  Victoria  940GZZLUSKW  940GZZLUVXL
# 2  Victoria  940GZZLUVXL  940GZZLUPCO
# 3  Victoria  940GZZLUPCO  940GZZLUVIC
# 4  Victoria  940GZZLUVIC  940GZZLUGPK
#
#                                             geometry
# 0  LINESTRING (531052.373 175421.812, 530495.102 ...
# 1  LINESTRING (530495.102 176472.794, 530418.543 ...
# 2  LINESTRING (530418.543 177894.234, 529721.855 ...
# 3  LINESTRING (529721.855 178312.504, 528987.452 ...
# 4  LINESTRING (528987.452 179124.792, 528966.363 ...

# %%
### Add geometry information back into the graph
for line_name in line_names:
    if line_name in excluded_lines :
        continue
    temp_lines = edge_gdf[edge_gdf.line_name == line_name]
    temp_stations = stations[stations.lines.str.contains(line_name)]
    
    #let's plot our lines so we can check them
    fig, ax = plt.subplots(figsize = (7,7))
    fig.suptitle(f'line: {line_name}')
    ax.set_aspect("equal")
    ax.axis('off')
    ax.margins(0.1)
    
    base = temp_lines.plot(ax=ax, color='grey')
    temp_stations.plot(ax=base, markersize=20, color='red')
    plt.show()
    
    #add real geometry back
    for i, edge in temp_lines.iterrows():
        #get start and end of line coordinates
        start = edge.geometry.coords[0]
        end = edge.geometry.coords[-1]
        
        #let's get all the coordinates in our geometric graph
        nodes = list(geometric_graphs[line_name].nodes)
        
        #find nearest node in graph to origin and destination
        s_dist = distance.cdist([start], nodes)[0]
        s_i = np.argmin(s_dist)
        source= nodes[s_i]
        
        t_dist = distance.cdist([end], nodes)[0]
        t_i = np.argmin(t_dist)
        target= nodes[t_i]
        
        #get shortest path
        sp = nx.shortest_path(geometric_graphs[line_name], source, target)
        
        #make into geometry
        #notice how I'm also adding the start and end coordinates to the line definition
        #this fixes the problem of stations and lines not matching up
        geometry = LineString([start] + sp + [end])
        edge_gdf.loc[i, 'geometry'] = geometry

# %%
#plot to sanity check
edge_gdf.plot()
# Out:
# <Axes: >

# %%
#let's store the length of the real geometry
edge_gdf['length'] = edge_gdf.geometry.length

# %%
#this is our resulting dataframe
edge_gdf.head()
# Out:
#   line_name     start_id       end_id  \
# 0  Victoria  940GZZLUBXN  940GZZLUSKW
# 1  Victoria  940GZZLUSKW  940GZZLUVXL
# 2  Victoria  940GZZLUVXL  940GZZLUPCO
# 3  Victoria  940GZZLUPCO  940GZZLUVIC
# 4  Victoria  940GZZLUVIC  940GZZLUGPK
#
#                                             geometry       length
# 0  LINESTRING (531052.373 175421.812, 531051.014 ...  1586.717477
# 1  LINESTRING (530495.102 176472.794, 530493.983 ...  1506.837919
# 2  LINESTRING (530418.543 177894.234, 530417.289 ...   825.314290
# 3  LINESTRING (529721.855 178312.504, 529720.474 ...  1399.851967
# 4  LINESTRING (528987.452 179124.792, 528988.139 ...  1209.575147

# %%
#let's replace the ids with the actual name
#get all station names
station_names_2 = {row.altmodeid: row['name'] for i, row in stations.iterrows() if row.altmodeid != None}
station_names.update(station_names_2)

# %%
edge_gdf['start_id'] = edge_gdf['start_id'].apply(lambda x: station_names[x])
edge_gdf['end_id'] = edge_gdf['end_id'].apply(lambda x: station_names[x])

# %%
edge_gdf.head()
# Out:
#   line_name   start_id      end_id  \
# 0  Victoria    Brixton   Stockwell
# 1  Victoria  Stockwell    Vauxhall
# 2  Victoria   Vauxhall     Pimlico
# 3  Victoria    Pimlico    Victoria
# 4  Victoria   Victoria  Green Park
#
#                                             geometry       length
# 0  LINESTRING (531052.373 175421.812, 531051.014 ...  1586.717477
# 1  LINESTRING (530495.102 176472.794, 530493.983 ...  1506.837919
# 2  LINESTRING (530418.543 177894.234, 530417.289 ...   825.314290
# 3  LINESTRING (529721.855 178312.504, 529720.474 ...  1399.851967
# 4  LINESTRING (528987.452 179124.792, 528988.139 ...  1209.575147

# %%
#now we can use this to create our network!
G = nx.from_pandas_edgelist(edge_gdf, source = 'start_id', target='end_id', edge_attr=['length', 'line_name'])

# %%
#let's plot
#notice that even though we created the real geometries, the graph still plots just straight line
#this is because networkx doesn't have a concept of a edge geometry
#however this is ok, since we only need the distance as weights, and that is already an attribute in our graph
pos = {row['name']: row.geometry.coords[0] for i, row in stations.iterrows() if row['name'] in G.nodes()}
Gcc = nx.connected_components(G)
for n in Gcc:
    G_sub = G.subgraph(n)
    lines = [data['line_name'] for u,v, data in G_sub.edges(data=True)]
    print(set(lines))
    nx.draw(G_sub, pos, node_size=4)
    plt.show()
# Out:
# {'Hammersmith & City', 'Circle', 'Piccadilly', 'Jubilee', 'Central', 'Waterloo & City', 'Victoria', 'District', 'TfL Rail', 'Bakerloo', 'Metropolitan', 'London Overground', 'Northern', 'DLR'}

# %%
#save position to graph
nx.set_node_attributes(G, pos, 'coords')

# %% [markdown]
# ### Sanity check our network

# %%
#check that all distances are greater or equal to euclidean distance
for u,v, data in G.edges(data=True):
    assert(data['length'] >= distance.euclidean(pos[u], pos[v]))

# %%
#if want to know what is the maximum distance between stations
max(dict(G.edges).items(), key=lambda x: x[1]['length'])
# Out:
# (('Wembley Park', 'Finchley Road'),
#  {'length': 7266.258259329394, 'line_name': 'Metropolitan'})

# %%
#if want to know to which stations Baker Street is directly connected to
Baker_Street = [(u,v) for  u,v in G.edges() if u == 'Baker Street' or v == 'Baker Street']
Baker_Street
# Out:
# [('Edgware Road', 'Baker Street'),
#  ('Baker Street', 'Great Portland Street'),
#  ('Baker Street', 'Finchley Road'),
#  ('Baker Street', 'Marylebone'),
#  ('Baker Street', "Regent's Park"),
#  ('Baker Street', 'Bond Street'),
#  ('Baker Street', "St. John's Wood")]

# %%
#We can also check the degree of the nodes in our network and check that they make sense
deg_london = nx.degree(G)

# %%
df = pd.DataFrame(index = dict(deg_london).keys())
df['degree'] = dict(deg_london).values()

# %%
df.sort_values('degree', ascending =False).head(20)
# Out:
#                           degree
# Stratford                      9
# Bank and Monument              8
# King's Cross St. Pancras       7
# Baker Street                   7
# Oxford Circus                  6
# Waterloo                       6
# Canning Town                   6
# Earl's Court                   6
# West Ham                       6
# Liverpool Street               6
# Green Park                     6
# Euston                         5
# Willesden Junction             5
# Shadwell                       5
# Turnham Green                  5
# Highbury & Islington           4
# Finsbury Park                  4
# Seven Sisters                  4
# Blackhorse Road                4
# Camden Town                    4

# %% [markdown]
# ### Merge Network with OD data
#
# ok, we are almost done!
#
# We have processed our raw data, now we need to combine the two (TLF OD and our Network). For this we need two types of merge:
#
# 1. add flows as weights to the network (to be able to calculate disruptions to the network)
# 2. create OD with distance for our spatial interaction models (for our spatial interaction models)

# %%
#check that our OD data and network data match
OD_names = set(london_OD_AMpeak.station_origin.unique())
network_names = set([n for n in G.nodes()])

# %%
network_names.symmetric_difference(OD_names)
# Out:
# {'Acton Main Line',
#  'Battersea Power Station',
#  'Hanwell',
#  'Hayes & Harlington',
#  'Heathrow Terminal 4 EL',
#  'Heathrow Terminals 123',
#  'Heathrow Terminals 2 & 3',
#  'Heathrow Terminals 2 & 3 EL',
#  'Nine Elms',
#  'Southall',
#  "Walthamstow Queen's Road",
#  'Walthamstow Queens Road',
#  'West Ealing'}

# %% [markdown]
# Ok, we have a few stations that don't match up. They are small enough that we can solve this quickly by creating a mapping between names of the stations that we can keep.
#
# * Battersea power station and Nine Elms data doesn't exist in our TFL data because the station wasn't opened when the data was collected. This was an extension of Northern line that opened recently.
# * Action Main Line, Hanwell, Hayes & Harlington, Southall, and West Ealing are part of crossrail which we are not considering

# %%
name_map = {
    'Heathrow Terminal 4 EL': 'Heathrow Terminal 4',
    'Heathrow Terminals 123': 'Heathrow Terminals 2 & 3',
    'Heathrow Terminals 2 & 3 EL': 'Heathrow Terminals 2 & 3',
    "Walthamstow Queen's Road": 'Walthamstow Queens Road'
}

# %%
london_OD_AMpeak.station_origin = london_OD_AMpeak.station_origin.apply(
    lambda x: name_map[x] if x in name_map.keys() else x
)
london_OD_AMpeak.station_destination = london_OD_AMpeak.station_destination.apply(
    lambda x: name_map[x] if x in name_map.keys() else x
)

# %%
#let's filter out the stations that we don't have in our network
OD_names = set(london_OD_AMpeak.station_origin.unique())
_filter = list(network_names.symmetric_difference(OD_names))
_filter
# Out:
# ['West Ealing',
#  'Nine Elms',
#  'Hanwell',
#  'Southall',
#  'Battersea Power Station',
#  'Acton Main Line',
#  'Hayes & Harlington']

# %%
london_OD_AMpeak = london_OD_AMpeak[~london_OD_AMpeak.station_origin.isin(_filter)]
london_OD_AMpeak = london_OD_AMpeak[~london_OD_AMpeak.station_destination.isin(_filter)]

# %% [markdown]
# **Add flow data to our network**
#
# Our TFL data contains flows for OD pairs, but we don't know the flows passing through each edge in our network. We will have to calculate this assuming fall people travelling from Origin to Destination station are taking the shortest path within the network.

# %%
#create a dictionary to store flows for all edges
flows = {(u,v): 0 for u,v in G.edges()}
flows
# Out:
# {('Brixton', 'Stockwell'): 0,
#  ('Stockwell', 'Vauxhall'): 0,
#  ('Stockwell', 'Oval'): 0,
#  ('Stockwell', 'Clapham North'): 0,
#  ('Vauxhall', 'Pimlico'): 0,
#  ('Pimlico', 'Victoria'): 0,
#  ('Victoria', 'Green Park'): 0,
#  ('Victoria', 'Sloane Square'): 0,
#  ('Victoria', "St. James's Park"): 0,
#  ('Green Park', 'Oxford Circus'): 0,
#  ('Green Park', 'Hyde Park Corner'): 0,
#  ('Green Park', 'Piccadilly Circus'): 0,
#  ('Green Park', 'Westminster'): 0,
#  ('Green Park', 'Bond Street'): 0,
#  ('Oxford Circus', 'Warren Street'): 0,
#  ('Oxford Circus', "Regent's Park"): 0,
#  ('Oxford Circus', 'Piccadilly Circus'): 0,
#  ('Oxford Circus', 'Bond Street'): 0,
#  ('Oxford Circus', 'Tottenham Court Road'): 0,
#  ('Warren Street', 'Euston'): 0,
#  ('Warren Street', 'Goodge Street'): 0,
#  ('Euston', "King's Cross St. Pancras"): 0,
#  ('Euston', 'Camden Town'): 0,
#  ('Euston', 'Mornington Crescent'): 0,
#  ('Euston', 'South Hampstead'): 0,
#  ("King's Cross St. Pancras", 'Highbury & Islington'): 0,
#  ("King's Cross St. Pancras", 'Euston Square'): 0,
#  ("King's Cross St. Pancras", 'Farringdon'): 0,
#  ("King's Cross St. Pancras", 'Angel'): 0,
#  ("King's Cross St. Pancras", 'Russell Square'): 0,
#  ("King's Cross St. Pancras", 'Caledonian Road'): 0,
#  ('Highbury & Islington', 'Finsbury Park'): 0,
#  ('Highbury & Islington', 'Caledonian Road & Barnsbury'): 0,
#  ('Highbury & Islington', 'Canonbury'): 0,
#  ('Finsbury Park', 'Seven Sisters'): 0,
#  ('Finsbury Park', 'Arsenal'): 0,
#  ('Finsbury Park', 'Manor House'): 0,
#  ('Seven Sisters', 'Tottenham Hale'): 0,
#  ('Seven Sisters', 'Stamford Hill'): 0,
#  ('Seven Sisters', 'Bruce Grove'): 0,
#  ('Tottenham Hale', 'Blackhorse Road'): 0,
#  ('Blackhorse Road', 'Walthamstow Central'): 0,
#  ('Blackhorse Road', 'South Tottenham'): 0,
#  ('Blackhorse Road', 'Walthamstow Queens Road'): 0,
#  ('Walthamstow Central', 'St James Street'): 0,
#  ('Walthamstow Central', 'Wood Street'): 0,
#  ("Earl's Court", 'Gloucester Road'): 0,
#  ("Earl's Court", 'West Kensington'): 0,
#  ("Earl's Court", 'West Brompton'): 0,
#  ("Earl's Court", 'High Street Kensington'): 0,
#  ("Earl's Court", 'Kensington'): 0,
#  ("Earl's Court", 'Barons Court'): 0,
#  ('Gloucester Road', 'South Kensington'): 0,
#  ('Gloucester Road', 'High Street Kensington'): 0,
#  ('West Kensington', 'Barons Court'): 0,
#  ('Barons Court', 'Hammersmith'): 0,
#  ('Hammersmith', 'Ravenscourt Park'): 0,
#  ('Hammersmith', 'Goldhawk Road'): 0,
#  ('Hammersmith', 'Turnham Green'): 0,
#  ('Ravenscourt Park', 'Stamford Brook'): 0,
#  ('Stamford Brook', 'Turnham Green'): 0,
#  ('Turnham Green', 'Chiswick Park'): 0,
#  ('Turnham Green', 'Gunnersbury'): 0,
#  ('Turnham Green', 'Acton Town'): 0,
#  ('Chiswick Park', 'Acton Town'): 0,
#  ('Acton Town', 'Ealing Common'): 0,
#  ('Acton Town', 'South Ealing'): 0,
#  ('Ealing Common', 'Ealing Broadway'): 0,
#  ('Ealing Common', 'North Ealing'): 0,
#  ('South Kensington', 'Sloane Square'): 0,
#  ('South Kensington', 'Knightsbridge'): 0,
#  ('Ealing Broadway', 'West Acton'): 0,
#  ('Richmond', 'Kew Gardens'): 0,
#  ('Kew Gardens', 'Gunnersbury'): 0,
#  ('Gunnersbury', 'South Acton'): 0,
#  ('West Brompton', 'Fulham Broadway'): 0,
#  ('West Brompton', 'Imperial Wharf'): 0,
#  ('West Brompton', 'Kensington'): 0,
#  ('Wimbledon', 'Wimbledon Park'): 0,
#  ('Wimbledon Park', 'Southfields'): 0,
#  ('Southfields', 'East Putney'): 0,
#  ('East Putney', 'Putney Bridge'): 0,
#  ('Putney Bridge', 'Parsons Green'): 0,
#  ('Parsons Green', 'Fulham Broadway'): 0,
#  ('High Street Kensington', 'Notting Hill Gate'): 0,
#  ('Notting Hill Gate', 'Bayswater'): 0,
#  ('Notting Hill Gate', 'Holland Park'): 0,
#  ('Notting Hill Gate', 'Queensway'): 0,
#  ('Bayswater', 'Paddington'): 0,
#  ('Paddington', 'Edgware Road'): 0,
#  ('Paddington', 'Royal Oak'): 0,
#  ('Paddington', 'Warwick Avenue'): 0,
#  ('Edgware Road', 'Baker Street'): 0,
#  ('Edgware Road', 'Marylebone'): 0,
#  ("St. James's Park", 'Westminster'): 0,
#  ('Westminster', 'Embankment'): 0,
#  ('Westminster', 'Waterloo'): 0,
#  ('Embankment', 'Temple'): 0,
#  ('Embankment', 'Charing Cross'): 0,
#  ('Embankment', 'Waterloo'): 0,
#  ('Temple', 'Blackfriars'): 0,
#  ('Blackfriars', 'Mansion House'): 0,
#  ('Mansion House', 'Cannon Street'): 0,
#  ('Cannon Street', 'Bank and Monument'): 0,
#  ('Bank and Monument', 'Tower Hill'): 0,
#  ('Bank and Monument', 'Moorgate'): 0,
#  ('Bank and Monument', 'London Bridge'): 0,
#  ('Bank and Monument', 'Waterloo'): 0,
#  ('Bank and Monument', "St. Paul's"): 0,
#  ('Bank and Monument', 'Liverpool Street'): 0,
#  ('Bank and Monument', 'Shadwell'): 0,
#  ('Tower Hill', 'Aldgate East'): 0,
#  ('Tower Hill', 'Aldgate'): 0,
#  ('Aldgate East', 'Whitechapel'): 0,
#  ('Aldgate East', 'Liverpool Street'): 0,
#  ('Whitechapel', 'Stepney Green'): 0,
#  ('Whitechapel', 'Shadwell'): 0,
#  ('Whitechapel', 'Shoreditch High Street'): 0,
#  ('Stepney Green', 'Mile End'): 0,
#  ('Mile End', 'Bow Road'): 0,
#  ('Mile End', 'Bethnal Green'): 0,
#  ('Mile End', 'Stratford'): 0,
#  ('Bow Road', 'Bromley-by-Bow'): 0,
#  ('Bromley-by-Bow', 'West Ham'): 0,
#  ('West Ham', 'Plaistow'): 0,
#  ('West Ham', 'Stratford'): 0,
#  ('West Ham', 'Canning Town'): 0,
#  ('West Ham', 'Abbey Road'): 0,
#  ('West Ham', 'Star Lane'): 0,
#  ('Plaistow', 'Upton Park'): 0,
#  ('Upton Park', 'East Ham'): 0,
#  ('East Ham', 'Barking'): 0,
#  ('Barking', 'Upney'): 0,
#  ('Barking', 'Woodgrange Park'): 0,
#  ('Upney', 'Becontree'): 0,
#  ('Becontree', 'Dagenham Heathway'): 0,
#  ('Dagenham Heathway', 'Dagenham East'): 0,
#  ('Dagenham East', 'Elm Park'): 0,
#  ('Elm Park', 'Hornchurch'): 0,
#  ('Hornchurch', 'Upminster Bridge'): 0,
#  ('Upminster Bridge', 'Upminster'): 0,
#  ('Upminster', 'Emerson Park'): 0,
#  ('Kensington', "Shepherd's Bush"): 0,
#  ('Uxbridge', 'Hillingdon'): 0,
#  ('Hillingdon', 'Ickenham'): 0,
#  ('Ickenham', 'Ruislip'): 0,
#  ('Ruislip', 'Ruislip Manor'): 0,
#  ('Ruislip Manor', 'Eastcote'): 0,
#  ('Eastcote', 'Rayners Lane'): 0,
#  ('Rayners Lane', 'West Harrow'): 0,
#  ('Rayners Lane', 'South Harrow'): 0,
#  ('West Harrow', 'Harrow-on-the-Hill'): 0,
#  ('Aldgate', 'Liverpool Street'): 0,
#  ('Liverpool Street', 'Moorgate'): 0,
#  ('Liverpool Street', 'Bethnal Green'): 0,
#  ('Liverpool Street', 'Stratford'): 0,
#  ('Baker Street', 'Great Portland Street'): 0,
#  ('Baker Street', 'Finchley Road'): 0,
#  ('Baker Street', 'Marylebone'): 0,
#  ('Baker Street', "Regent's Park"): 0,
#  ('Baker Street', 'Bond Street'): 0,
#  ('Baker Street', "St. John's Wood"): 0,
#  ('Great Portland Street', 'Euston Square'): 0,
#  ('Farringdon', 'Barbican'): 0,
#  ('Barbican', 'Moorgate'): 0,
#  ('Moorgate', 'Old Street'): 0,
#  ('Harrow-on-the-Hill', 'North Harrow'): 0,
#  ('Harrow-on-the-Hill', 'Northwick Park'): 0,
#  ('Amersham', 'Chalfont & Latimer'): 0,
#  ('Chalfont & Latimer', 'Chorleywood'): 0,
#  ('Chalfont & Latimer', 'Chesham'): 0,
#  ('Chorleywood', 'Rickmansworth'): 0,
#  ('Rickmansworth', 'Moor Park'): 0,
#  ('Moor Park', 'Northwood'): 0,
#  ('Moor Park', 'Croxley'): 0,
#  ('Northwood', 'Northwood Hills'): 0,
#  ('Northwood Hills', 'Pinner'): 0,
#  ('Pinner', 'North Harrow'): 0,
#  ('Northwick Park', 'Preston Road'): 0,
#  ('Preston Road', 'Wembley Park'): 0,
#  ('Wembley Park', 'Finchley Road'): 0,
#  ('Wembley Park', 'Kingsbury'): 0,
#  ('Wembley Park', 'Neasden'): 0,
#  ('Croxley', 'Watford'): 0,
#  ('Finchley Road', 'Swiss Cottage'): 0,
#  ('Finchley Road', 'West Hampstead'): 0,
#  ('Edgware', 'Burnt Oak'): 0,
#  ('Burnt Oak', 'Colindale'): 0,
#  ('Colindale', 'Hendon Central'): 0,
#  ('Hendon Central', 'Brent Cross'): 0,
#  ('Brent Cross', 'Golders Green'): 0,
#  ('Golders Green', 'Hampstead'): 0,
#  ('Hampstead', 'Belsize Park'): 0,
#  ('Belsize Park', 'Chalk Farm'): 0,
#  ('Chalk Farm', 'Camden Town'): 0,
#  ('Camden Town', 'Kentish Town'): 0,
#  ('Camden Town', 'Mornington Crescent'): 0,
#  ('Angel', 'Old Street'): 0,
#  ('London Bridge', 'Borough'): 0,
#  ('London Bridge', 'Bermondsey'): 0,
#  ('London Bridge', 'Southwark'): 0,
#  ('Borough', 'Elephant & Castle'): 0,
#  ('Elephant & Castle', 'Kennington'): 0,
#  ('Elephant & Castle', 'Lambeth North'): 0,
#  ('Kennington', 'Oval'): 0,
#  ('Kennington', 'Waterloo'): 0,
#  ('Kennington', 'Nine Elms'): 0,
#  ('Clapham North', 'Clapham Common'): 0,
#  ('Clapham Common', 'Clapham South'): 0,
#  ('Clapham South', 'Balham'): 0,
#  ('Balham', 'Tooting Bec'): 0,
#  ('Tooting Bec', 'Tooting Broadway'): 0,
#  ('Tooting Broadway', 'Colliers Wood'): 0,
#  ('Colliers Wood', 'South Wimbledon'): 0,
#  ('South Wimbledon', 'Morden'): 0,
#  ('Finchley Central', 'Mill Hill East'): 0,
#  ('Finchley Central', 'West Finchley'): 0,
#  ('Finchley Central', 'East Finchley'): 0,
#  ('Charing Cross', 'Leicester Square'): 0,
#  ('Charing Cross', 'Piccadilly Circus'): 0,
#  ('Waterloo', 'Lambeth North'): 0,
#  ('Waterloo', 'Southwark'): 0,
#  ('High Barnet', 'Totteridge & Whetstone'): 0,
#  ('Totteridge & Whetstone', 'Woodside Park'): 0,
#  ('Woodside Park', 'West Finchley'): 0,
#  ('East Finchley', 'Highgate'): 0,
#  ('Highgate', 'Archway'): 0,
#  ('Archway', 'Tufnell Park'): 0,
#  ('Tufnell Park', 'Kentish Town'): 0,
#  ('Goodge Street', 'Tottenham Court Road'): 0,
#  ('Tottenham Court Road', 'Leicester Square'): 0,
#  ('Tottenham Court Road', 'Holborn'): 0,
#  ('Leicester Square', 'Piccadilly Circus'): 0,
#  ('Leicester Square', 'Covent Garden'): 0,
#  ('Battersea Power Station', 'Nine Elms'): 0,
#  ('Goldhawk Road', "Shepherd's Bush Market"): 0,
#  ("Shepherd's Bush Market", 'Wood Lane'): 0,
#  ('Wood Lane', 'Latimer Road'): 0,
#  ('Latimer Road', 'Ladbroke Grove'): 0,
#  ('Ladbroke Grove', 'Westbourne Park'): 0,
#  ('Westbourne Park', 'Royal Oak'): 0,
#  ('Harrow & Wealdstone', 'Kenton'): 0,
#  ('Harrow & Wealdstone', 'Headstone Lane'): 0,
#  ('Kenton', 'South Kenton'): 0,
#  ('South Kenton', 'North Wembley'): 0,
#  ('North Wembley', 'Wembley Central'): 0,
#  ('Wembley Central', 'Stonebridge Park'): 0,
#  ('Stonebridge Park', 'Harlesden'): 0,
#  ('Harlesden', 'Willesden Junction'): 0,
#  ('Willesden Junction', 'Kensal Green'): 0,
#  ('Willesden Junction', 'Acton Central'): 0,
#  ('Willesden Junction', 'Kensal Rise'): 0,
#  ('Willesden Junction', "Shepherd's Bush"): 0,
#  ('Kensal Green', "Queen's Park"): 0,
#  ("Queen's Park", 'Kilburn Park'): 0,
#  ("Queen's Park", 'Kilburn High Road'): 0,
#  ('Kilburn Park', 'Maida Vale'): 0,
#  ('Maida Vale', 'Warwick Avenue'): 0,
#  ('Cambridge Heath', 'Bethnal Green'): 0,
#  ('Cambridge Heath', 'London Fields'): 0,
#  ('London Fields', 'Hackney Downs'): 0,
#  ('Hackney Downs', 'Rectory Road'): 0,
#  ('Hackney Downs', 'Clapton'): 0,
#  ('Rectory Road', 'Stoke Newington'): 0,
#  ('Stoke Newington', 'Stamford Hill'): 0,
#  ('Bruce Grove', 'White Hart Lane'): 0,
#  ('White Hart Lane', 'Silver Street'): 0,
#  ('Silver Street', 'Edmonton Green'): 0,
#  ('Edmonton Green', 'Southbury'): 0,
#  ('Edmonton Green', 'Bush Hill Park'): 0,
#  ('Southbury', 'Turkey Street'): 0,
#  ('Turkey Street', 'Theobalds Grove'): 0,
#  ('Theobalds Grove', 'Cheshunt'): 0,
#  ('Enfield Town', 'Bush Hill Park'): 0,
#  ('Romford', 'Emerson Park'): 0,
#  ('Romford', 'Chadwell Heath'): 0,
#  ('Romford', 'Gidea Park'): 0,
#  ('Clapton', 'St James Street'): 0,
#  ('Wood Street', 'Highams Park'): 0,
#  ('Highams Park', 'Chingford'): 0,
#  ('South Acton', 'Acton Central'): 0,
#  ('Kilburn High Road', 'South Hampstead'): 0,
#  ('Kensal Rise', 'Brondesbury Park'): 0,
#  ('Brondesbury Park', 'Brondesbury'): 0,
#  ('Brondesbury', 'West Hampstead'): 0,
#  ('West Hampstead', 'Finchley Road & Frognal'): 0,
#  ('West Hampstead', 'Kilburn'): 0,
#  ('Finchley Road & Frognal', 'Hampstead Heath'): 0,
#  ('Hampstead Heath', 'Gospel Oak'): 0,
#  ('Gospel Oak', 'Kentish Town West'): 0,
#  ('Gospel Oak', 'Upper Holloway'): 0,
#  ('Kentish Town West', 'Camden Road'): 0,
#  ('Camden Road', 'Caledonian Road & Barnsbury'): 0,
#  ('Canonbury', 'Dalston Kingsland'): 0,
#  ('Canonbury', 'Dalston Junction'): 0,
#  ('Dalston Kingsland', 'Hackney Central'): 0,
#  ('Hackney Central', 'Homerton'): 0,
#  ('Homerton', 'Hackney Wick'): 0,
#  ('Hackney Wick', 'Stratford'): 0,
#  ('Stratford', 'Leyton'): 0,
#  ('Stratford', 'Maryland'): 0,
#  ('Stratford', 'Stratford High Street'): 0,
#  ('Stratford', 'Pudding Mill Lane'): 0,
#  ('Stratford', 'Stratford International'): 0,
#  ('Shadwell', 'Wapping'): 0,
#  ('Shadwell', 'Limehouse'): 0,
#  ('Shadwell', 'Tower Gateway'): 0,
#  ('Wapping', 'Rotherhithe'): 0,
#  ('Rotherhithe', 'Canada Water'): 0,
#  ('Canada Water', 'Surrey Quays'): 0,
#  ('Canada Water', 'Canary Wharf'): 0,
#  ('Canada Water', 'Bermondsey'): 0,
#  ('Surrey Quays', 'New Cross Gate'): 0,
#  ('Surrey Quays', 'New Cross'): 0,
#  ('Surrey Quays', 'Queens Road Peckham'): 0,
#  ('New Cross Gate', 'Brockley'): 0,
#  ('Shoreditch High Street', 'Hoxton'): 0,
#  ('Sydenham', 'Crystal Palace'): 0,
#  ('Sydenham', 'Forest Hill'): 0,
#  ('Sydenham', 'Penge West'): 0,
#  ('Queens Road Peckham', 'Peckham Rye'): 0,
#  ('Peckham Rye', 'Denmark Hill'): 0,
#  ('Denmark Hill', 'Clapham High Street'): 0,
#  ('Clapham High Street', 'Wandsworth Road'): 0,
#  ('Wandsworth Road', 'Clapham Junction'): 0,
#  ('Wandsworth Road', 'Battersea Park'): 0,
#  ('Clapham Junction', 'Imperial Wharf'): 0,
#  ('Bushey', 'Watford High Street'): 0,
#  ('Bushey', 'Carpenders Park'): 0,
#  ('Watford High Street', 'Watford Junction'): 0,
#  ('Carpenders Park', 'Hatch End'): 0,
#  ('Hatch End', 'Headstone Lane'): 0,
#  ('Upper Holloway', 'Crouch Hill'): 0,
#  ('Crouch Hill', 'Harringay Green Lanes'): 0,
#  ('Harringay Green Lanes', 'South Tottenham'): 0,
#  ('Walthamstow Queens Road', 'Leyton Midland Road'): 0,
#  ('Leyton Midland Road', 'Leytonstone High Road'): 0,
#  ('Leytonstone High Road', 'Wanstead Park'): 0,
#  ('Wanstead Park', 'Woodgrange Park'): 0,
#  ('Brockley', 'Honor Oak Park'): 0,
#  ('Honor Oak Park', 'Forest Hill'): 0,
#  ('Penge West', 'Anerley'): 0,
#  ('Anerley', 'Norwood Junction'): 0,
#  ('Norwood Junction', 'West Croydon'): 0,
#  ('Dalston Junction', 'Haggerston'): 0,
#  ('Haggerston', 'Hoxton'): 0,
#  ("Shepherd's Bush", 'White City'): 0,
#  ("Shepherd's Bush", 'Holland Park'): 0,
#  ('South Ealing', 'Northfields'): 0,
#  ('Knightsbridge', 'Hyde Park Corner'): 0,
#  ('Covent Garden', 'Holborn'): 0,
#  ('Holborn', 'Russell Square'): 0,
#  ('Holborn', 'Chancery Lane'): 0,
#  ('Caledonian Road', 'Holloway Road'): 0,
#  ('Holloway Road', 'Arsenal'): 0,
#  ('Manor House', 'Turnpike Lane'): 0,
#  ('Turnpike Lane', 'Wood Green'): 0,
#  ('Wood Green', 'Bounds Green'): 0,
#  ('Bounds Green', 'Arnos Grove'): 0,
#  ('Arnos Grove', 'Southgate'): 0,
#  ('Southgate', 'Oakwood'): 0,
#  ('Oakwood', 'Cockfosters'): 0,
#  ('South Harrow', 'Sudbury Hill'): 0,
#  ('Sudbury Hill', 'Sudbury Town'): 0,
#  ('Sudbury Town', 'Alperton'): 0,
#  ('Alperton', 'Park Royal'): 0,
#  ('Park Royal', 'North Ealing'): 0,
#  ('Heathrow Terminal 4', 'Hatton Cross'): 0,
#  ('Heathrow Terminal 4', 'Heathrow Terminals 2 & 3'): 0,
#  ('Hatton Cross', 'Heathrow Terminals 2 & 3'): 0,
#  ('Hatton Cross', 'Hounslow West'): 0,
#  ('Heathrow Terminals 2 & 3', 'Heathrow Terminal 5'): 0,
#  ('Hounslow West', 'Hounslow Central'): 0,
#  ('Hounslow Central', 'Hounslow East'): 0,
#  ('Hounslow East', 'Osterley'): 0,
#  ('Osterley', 'Boston Manor'): 0,
#  ('Boston Manor', 'Northfields'): 0,
#  ('West Acton', 'North Acton'): 0,
#  ('North Acton', 'Hanger Lane'): 0,
#  ('North Acton', 'East Acton'): 0,
#  ('West Ruislip', 'Ruislip Gardens'): 0,
#  ('Ruislip Gardens', 'South Ruislip'): 0,
#  ('South Ruislip', 'Northolt'): 0,
#  ('Northolt', 'Greenford'): 0,
#  ('Greenford', 'Perivale'): 0,
#  ('Perivale', 'Hanger Lane'): 0,
#  ('East Acton', 'White City'): 0,
#  ('Queensway', 'Lancaster Gate'): 0,
#  ('Lancaster Gate', 'Marble Arch'): 0,
#  ('Marble Arch', 'Bond Street'): 0,
#  ('Chancery Lane', "St. Paul's"): 0,
#  ('Leyton', 'Leytonstone'): 0,
#  ('Leytonstone', 'Snaresbrook'): 0,
#  ('Leytonstone', 'Wanstead'): 0,
#  ('Snaresbrook', 'South Woodford'): 0,
#  ('South Woodford', 'Woodford'): 0,
#  ('Woodford', 'Buckhurst Hill'): 0,
#  ('Woodford', 'Roding Valley'): 0,
#  ('Buckhurst Hill', 'Loughton'): 0,
#  ('Loughton', 'Debden'): 0,
#  ('Debden', 'Theydon Bois'): 0,
#  ('Theydon Bois', 'Epping'): 0,
#  ('Wanstead', 'Redbridge'): 0,
#  ('Redbridge', 'Gants Hill'): 0,
#  ('Gants Hill', 'Newbury Park'): 0,
#  ('Newbury Park', 'Barkingside'): 0,
#  ('Barkingside', 'Fairlop'): 0,
#  ('Fairlop', 'Hainault'): 0,
#  ('Hainault', 'Grange Hill'): 0,
#  ('Grange Hill', 'Chigwell'): 0,
#  ('Chigwell', 'Roding Valley'): 0,
#  ('Kingsbury', 'Queensbury'): 0,
#  ('Queensbury', 'Canons Park'): 0,
#  ('Canons Park', 'Stanmore'): 0,
#  ('Canning Town', 'North Greenwich'): 0,
#  ('Canning Town', 'Star Lane'): 0,
#  ('Canning Town', 'Royal Victoria'): 0,
#  ('Canning Town', 'East India'): 0,
#  ('Canning Town', 'West Silvertown'): 0,
#  ('North Greenwich', 'Canary Wharf'): 0,
#  ('Canary Wharf', 'West India Quay'): 0,
#  ('Canary Wharf', 'Heron Quays'): 0,
#  ("St. John's Wood", 'Swiss Cottage'): 0,
#  ('Neasden', 'Dollis Hill'): 0,
#  ('Dollis Hill', 'Willesden Green'): 0,
#  ('Willesden Green', 'Kilburn'): 0,
#  ('Maryland', 'Forest Gate'): 0,
#  ('Forest Gate', 'Manor Park'): 0,
#  ('Manor Park', 'Ilford'): 0,
#  ('Ilford', 'Seven Kings'): 0,
#  ('Seven Kings', 'Goodmayes'): 0,
#  ('Goodmayes', 'Chadwell Heath'): 0,
#  ('Gidea Park', 'Harold Wood'): 0,
#  ('Harold Wood', 'Brentwood'): 0,
#  ('Brentwood', 'Shenfield'): 0,
#  ('Stratford High Street', 'Abbey Road'): 0,
#  ('Royal Victoria', 'Custom House'): 0,
#  ('Limehouse', 'Westferry'): 0,
#  ('Westferry', 'West India Quay'): 0,
#  ('Westferry', 'Poplar'): 0,
#  ('West India Quay', 'Poplar'): 0,
#  ('Heron Quays', 'South Quay'): 0,
#  ('South Quay', 'Crossharbour'): 0,
#  ('Crossharbour', 'Mudchute'): 0,
#  ('Mudchute', 'Island Gardens'): 0,
#  ('Island Gardens', 'Cutty Sark'): 0,
#  ('Cutty Sark', 'Greenwich'): 0,
#  ('Greenwich', 'Deptford Bridge'): 0,
#  ('Deptford Bridge', 'Elverson Road'): 0,
#  ('Elverson Road', 'Lewisham'): 0,
#  ('Poplar', 'All Saints'): 0,
#  ('Poplar', 'Blackwall'): 0,
#  ('All Saints', 'Langdon Park'): 0,
#  ('Blackwall', 'East India'): 0,
#  ('Custom House', 'Prince Regent'): 0,
#  ('Prince Regent', 'Royal Albert'): 0,
#  ('Royal Albert', 'Beckton Park'): 0,
#  ('Beckton Park', 'Cyprus'): 0,
#  ('Cyprus', 'Gallions Reach'): 0,
#  ('Gallions Reach', 'Beckton'): 0,
#  ('Langdon Park', 'Devons Road'): 0,
#  ('Devons Road', 'Bow Church'): 0,
#  ('Bow Church', 'Pudding Mill Lane'): 0,
#  ('Woolwich Arsenal', 'King George V'): 0,
#  ('King George V', 'London City Airport'): 0,
#  ('West Silvertown', 'Pontoon Dock'): 0,
#  ('Pontoon Dock', 'London City Airport'): 0}

# %%
#This is adding the number of flows for each OD journey to all of the edges on the shortest path

#calculate shortest paths for all flows and add data to dict
for i, row in london_OD_AMpeak.iterrows():
    source = row.station_origin
    target = row.station_destination
    
    #get shortest path
    path = nx.dijkstra_path(G, source, target)
    
    #our path is a list of nodes, we need to turn this to a list of edges
    path_edges = list(zip(path,path[1:])) 
    
    #add flows to our dict
    for u,v in path_edges:
        try:
            flows[(u,v)] += row.flows
        except:
            flows[(v,u)] += row.flows

# %%
flows
# Out:
# {('Brixton', 'Stockwell'): 28465,
#  ('Stockwell', 'Vauxhall'): 57015,
#  ('Stockwell', 'Oval'): 51232,
#  ('Stockwell', 'Clapham North'): 59928,
#  ('Vauxhall', 'Pimlico'): 71783,
#  ('Pimlico', 'Victoria'): 78233,
#  ('Victoria', 'Green Park'): 188370,
#  ('Victoria', 'Sloane Square'): 121279,
#  ('Victoria', "St. James's Park"): 38254,
#  ('Green Park', 'Oxford Circus'): 138959,
#  ('Green Park', 'Hyde Park Corner'): 7950,
#  ('Green Park', 'Piccadilly Circus'): 8618,
#  ('Green Park', 'Westminster'): 177755,
#  ('Green Park', 'Bond Street'): 113476,
#  ('Oxford Circus', 'Warren Street'): 130025,
#  ('Oxford Circus', "Regent's Park"): 19048,
#  ('Oxford Circus', 'Piccadilly Circus'): 17209,
#  ('Oxford Circus', 'Bond Street'): 13026,
#  ('Oxford Circus', 'Tottenham Court Road'): 25661,
#  ('Warren Street', 'Euston'): 129664,
#  ('Warren Street', 'Goodge Street'): 3831,
#  ('Euston', "King's Cross St. Pancras"): 152980,
#  ('Euston', 'Camden Town'): 73814,
#  ('Euston', 'Mornington Crescent'): 2542,
#  ('Euston', 'South Hampstead'): 38770,
#  ("King's Cross St. Pancras", 'Highbury & Islington'): 124286,
#  ("King's Cross St. Pancras", 'Euston Square'): 48825,
#  ("King's Cross St. Pancras", 'Farringdon'): 106867,
#  ("King's Cross St. Pancras", 'Angel'): 13732,
#  ("King's Cross St. Pancras", 'Russell Square'): 22640,
#  ("King's Cross St. Pancras", 'Caledonian Road'): 10533,
#  ('Highbury & Islington', 'Finsbury Park'): 110124,
#  ('Highbury & Islington', 'Caledonian Road & Barnsbury'): 9057,
#  ('Highbury & Islington', 'Canonbury'): 21418,
#  ('Finsbury Park', 'Seven Sisters'): 55820,
#  ('Finsbury Park', 'Arsenal'): 1235,
#  ('Finsbury Park', 'Manor House'): 34661,
#  ('Seven Sisters', 'Tottenham Hale'): 34493,
#  ('Seven Sisters', 'Stamford Hill'): 3813,
#  ('Seven Sisters', 'Bruce Grove'): 12361,
#  ('Tottenham Hale', 'Blackhorse Road'): 24331,
#  ('Blackhorse Road', 'Walthamstow Central'): 15696,
#  ('Blackhorse Road', 'South Tottenham'): 3312,
#  ('Blackhorse Road', 'Walthamstow Queens Road'): 4751,
#  ('Walthamstow Central', 'St James Street'): 8717,
#  ('Walthamstow Central', 'Wood Street'): 7003,
#  ("Earl's Court", 'Gloucester Road'): 97484,
#  ("Earl's Court", 'West Kensington'): 3196,
#  ("Earl's Court", 'West Brompton'): 34923,
#  ("Earl's Court", 'High Street Kensington'): 14157,
#  ("Earl's Court", 'Kensington'): 16809,
#  ("Earl's Court", 'Barons Court'): 68030,
#  ('Gloucester Road', 'South Kensington'): 108151,
#  ('Gloucester Road', 'High Street Kensington'): 7016,
#  ('West Kensington', 'Barons Court'): 864,
#  ('Barons Court', 'Hammersmith'): 65460,
#  ('Hammersmith', 'Ravenscourt Park'): 4442,
#  ('Hammersmith', 'Goldhawk Road'): 5406,
#  ('Hammersmith', 'Turnham Green'): 49124,
#  ('Ravenscourt Park', 'Stamford Brook'): 2567,
#  ('Stamford Brook', 'Turnham Green'): 1624,
#  ('Turnham Green', 'Chiswick Park'): 1710,
#  ('Turnham Green', 'Gunnersbury'): 15213,
#  ('Turnham Green', 'Acton Town'): 42736,
#  ('Chiswick Park', 'Acton Town'): 1090,
#  ('Acton Town', 'Ealing Common'): 21845,
#  ('Acton Town', 'South Ealing'): 23406,
#  ('Ealing Common', 'Ealing Broadway'): 12431,
#  ('Ealing Common', 'North Ealing'): 8770,
#  ('South Kensington', 'Sloane Square'): 114803,
#  ('South Kensington', 'Knightsbridge'): 2655,
#  ('Ealing Broadway', 'West Acton'): 6306,
#  ('Richmond', 'Kew Gardens'): 10554,
#  ('Kew Gardens', 'Gunnersbury'): 12513,
#  ('Gunnersbury', 'South Acton'): 12649,
#  ('West Brompton', 'Fulham Broadway'): 34820,
#  ('West Brompton', 'Imperial Wharf'): 14604,
#  ('West Brompton', 'Kensington'): 15213,
#  ('Wimbledon', 'Wimbledon Park'): 13368,
#  ('Wimbledon Park', 'Southfields'): 14088,
#  ('Southfields', 'East Putney'): 17370,
#  ('East Putney', 'Putney Bridge'): 22123,
#  ('Putney Bridge', 'Parsons Green'): 25641,
#  ('Parsons Green', 'Fulham Broadway'): 30177,
#  ('High Street Kensington', 'Notting Hill Gate'): 17591,
#  ('Notting Hill Gate', 'Bayswater'): 18642,
#  ('Notting Hill Gate', 'Holland Park'): 13072,
#  ('Notting Hill Gate', 'Queensway'): 14142,
#  ('Bayswater', 'Paddington'): 18388,
#  ('Paddington', 'Edgware Road'): 56869,
#  ('Paddington', 'Royal Oak'): 11665,
#  ('Paddington', 'Warwick Avenue'): 6399,
#  ('Edgware Road', 'Baker Street'): 59659,
#  ('Edgware Road', 'Marylebone'): 1227,
#  ("St. James's Park", 'Westminster'): 38784,
#  ('Westminster', 'Embankment'): 23605,
#  ('Westminster', 'Waterloo'): 194195,
#  ('Embankment', 'Temple'): 22792,
#  ('Embankment', 'Charing Cross'): 14452,
#  ('Embankment', 'Waterloo'): 25666,
#  ('Temple', 'Blackfriars'): 16629,
#  ('Blackfriars', 'Mansion House'): 12717,
#  ('Mansion House', 'Cannon Street'): 9302,
#  ('Cannon Street', 'Bank and Monument'): 16126,
#  ('Bank and Monument', 'Tower Hill'): 24847,
#  ('Bank and Monument', 'Moorgate'): 70548,
#  ('Bank and Monument', 'London Bridge'): 115237,
#  ('Bank and Monument', 'Waterloo'): 248335,
#  ('Bank and Monument', "St. Paul's"): 35351,
#  ('Bank and Monument', 'Liverpool Street'): 147211,
#  ('Bank and Monument', 'Shadwell'): 20596,
#  ('Tower Hill', 'Aldgate East'): 6880,
#  ('Tower Hill', 'Aldgate'): 4780,
#  ('Aldgate East', 'Whitechapel'): 5533,
#  ('Aldgate East', 'Liverpool Street'): 7241,
#  ('Whitechapel', 'Stepney Green'): 10862,
#  ('Whitechapel', 'Shadwell'): 27570,
#  ('Whitechapel', 'Shoreditch High Street'): 15841,
#  ('Stepney Green', 'Mile End'): 9220,
#  ('Mile End', 'Bow Road'): 4960,
#  ('Mile End', 'Bethnal Green'): 12993,
#  ('Mile End', 'Stratford'): 11885,
#  ('Bow Road', 'Bromley-by-Bow'): 1480,
#  ('Bromley-by-Bow', 'West Ham'): 4270,
#  ('West Ham', 'Plaistow'): 33685,
#  ('West Ham', 'Stratford'): 92497,
#  ('West Ham', 'Canning Town'): 60985,
#  ('West Ham', 'Abbey Road'): 601,
#  ('West Ham', 'Star Lane'): 1038,
#  ('Plaistow', 'Upton Park'): 30806,
#  ('Upton Park', 'East Ham'): 25417,
#  ('East Ham', 'Barking'): 17999,
#  ('Barking', 'Upney'): 15044,
#  ('Barking', 'Woodgrange Park'): 3305,
#  ('Upney', 'Becontree'): 13312,
#  ('Becontree', 'Dagenham Heathway'): 11305,
#  ('Dagenham Heathway', 'Dagenham East'): 7623,
#  ('Dagenham East', 'Elm Park'): 5556,
#  ('Elm Park', 'Hornchurch'): 3139,
#  ('Hornchurch', 'Upminster Bridge'): 1488,
#  ('Upminster Bridge', 'Upminster'): 1330,
#  ('Upminster', 'Emerson Park'): 1211,
#  ('Kensington', "Shepherd's Bush"): 31610,
#  ('Uxbridge', 'Hillingdon'): 7080,
#  ('Hillingdon', 'Ickenham'): 8453,
#  ('Ickenham', 'Ruislip'): 8984,
#  ('Ruislip', 'Ruislip Manor'): 9700,
#  ('Ruislip Manor', 'Eastcote'): 10497,
#  ('Eastcote', 'Rayners Lane'): 12414,
#  ('Rayners Lane', 'West Harrow'): 13755,
#  ('Rayners Lane', 'South Harrow'): 5239,
#  ('West Harrow', 'Harrow-on-the-Hill'): 14386,
#  ('Aldgate', 'Liverpool Street'): 8074,
#  ('Liverpool Street', 'Moorgate'): 50025,
#  ('Liverpool Street', 'Bethnal Green'): 30790,
#  ('Liverpool Street', 'Stratford'): 148798,
#  ('Baker Street', 'Great Portland Street'): 45606,
#  ('Baker Street', 'Finchley Road'): 74754,
#  ('Baker Street', 'Marylebone'): 9148,
#  ('Baker Street', "Regent's Park"): 17025,
#  ('Baker Street', 'Bond Street'): 89252,
#  ('Baker Street', "St. John's Wood"): 10259,
#  ('Great Portland Street', 'Euston Square'): 46168,
#  ('Farringdon', 'Barbican'): 100641,
#  ('Barbican', 'Moorgate'): 99860,
#  ('Moorgate', 'Old Street'): 19531,
#  ('Harrow-on-the-Hill', 'North Harrow'): 15498,
#  ('Harrow-on-the-Hill', 'Northwick Park'): 32987,
#  ('Amersham', 'Chalfont & Latimer'): 1446,
#  ('Chalfont & Latimer', 'Chorleywood'): 3319,
#  ('Chalfont & Latimer', 'Chesham'): 1175,
#  ('Chorleywood', 'Rickmansworth'): 4587,
#  ('Rickmansworth', 'Moor Park'): 5990,
#  ('Moor Park', 'Northwood'): 9606,
#  ('Moor Park', 'Croxley'): 3414,
#  ('Northwood', 'Northwood Hills'): 11621,
#  ('Northwood Hills', 'Pinner'): 12581,
#  ('Pinner', 'North Harrow'): 14326,
#  ('Northwick Park', 'Preston Road'): 35252,
#  ('Preston Road', 'Wembley Park'): 36563,
#  ('Wembley Park', 'Finchley Road'): 55178,
#  ('Wembley Park', 'Kingsbury'): 12356,
#  ('Wembley Park', 'Neasden'): 6744,
#  ('Croxley', 'Watford'): 2361,
#  ('Finchley Road', 'Swiss Cottage'): 2954,
#  ('Finchley Road', 'West Hampstead'): 22963,
#  ('Edgware', 'Burnt Oak'): 4177,
#  ('Burnt Oak', 'Colindale'): 7651,
#  ('Colindale', 'Hendon Central'): 14377,
#  ('Hendon Central', 'Brent Cross'): 19124,
#  ('Brent Cross', 'Golders Green'): 20220,
#  ('Golders Green', 'Hampstead'): 24767,
#  ('Hampstead', 'Belsize Park'): 27009,
#  ('Belsize Park', 'Chalk Farm'): 30238,
#  ('Chalk Farm', 'Camden Town'): 33160,
#  ('Camden Town', 'Kentish Town'): 40446,
#  ('Camden Town', 'Mornington Crescent'): 1076,
#  ('Angel', 'Old Street'): 14956,
#  ('London Bridge', 'Borough'): 16019,
#  ('London Bridge', 'Bermondsey'): 78874,
#  ('London Bridge', 'Southwark'): 8219,
#  ('Borough', 'Elephant & Castle'): 14715,
#  ('Elephant & Castle', 'Kennington'): 19007,
#  ('Elephant & Castle', 'Lambeth North'): 94,
#  ('Kennington', 'Oval'): 54575,
#  ('Kennington', 'Waterloo'): 56230,
#  ('Kennington', 'Nine Elms'): 0,
#  ('Clapham North', 'Clapham Common'): 57688,
#  ('Clapham Common', 'Clapham South'): 52799,
#  ('Clapham South', 'Balham'): 46040,
#  ('Balham', 'Tooting Bec'): 37941,
#  ('Tooting Bec', 'Tooting Broadway'): 31330,
#  ('Tooting Broadway', 'Colliers Wood'): 20004,
#  ('Colliers Wood', 'South Wimbledon'): 14194,
#  ('South Wimbledon', 'Morden'): 9482,
#  ('Finchley Central', 'Mill Hill East'): 1974,
#  ('Finchley Central', 'West Finchley'): 11555,
#  ('Finchley Central', 'East Finchley'): 19938,
#  ('Charing Cross', 'Leicester Square'): 8253,
#  ('Charing Cross', 'Piccadilly Circus'): 14276,
#  ('Waterloo', 'Lambeth North'): 2339,
#  ('Waterloo', 'Southwark'): 6989,
#  ('High Barnet', 'Totteridge & Whetstone'): 4224,
#  ('Totteridge & Whetstone', 'Woodside Park'): 6700,
#  ('Woodside Park', 'West Finchley'): 10150,
#  ('East Finchley', 'Highgate'): 25789,
#  ('Highgate', 'Archway'): 30286,
#  ('Archway', 'Tufnell Park'): 35715,
#  ('Tufnell Park', 'Kentish Town'): 38298,
#  ('Goodge Street', 'Tottenham Court Road'): 3556,
#  ('Tottenham Court Road', 'Leicester Square'): 6241,
#  ('Tottenham Court Road', 'Holborn'): 26301,
#  ('Leicester Square', 'Piccadilly Circus'): 7081,
#  ('Leicester Square', 'Covent Garden'): 4145,
#  ('Battersea Power Station', 'Nine Elms'): 0,
#  ('Goldhawk Road', "Shepherd's Bush Market"): 4123,
#  ("Shepherd's Bush Market", 'Wood Lane'): 4735,
#  ('Wood Lane', 'Latimer Road'): 5827,
#  ('Latimer Road', 'Ladbroke Grove'): 6475,
#  ('Ladbroke Grove', 'Westbourne Park'): 8579,
#  ('Westbourne Park', 'Royal Oak'): 10238,
#  ('Harrow & Wealdstone', 'Kenton'): 5132,
#  ('Harrow & Wealdstone', 'Headstone Lane'): 3456,
#  ('Kenton', 'South Kenton'): 5933,
#  ('South Kenton', 'North Wembley'): 6707,
#  ('North Wembley', 'Wembley Central'): 7477,
#  ('Wembley Central', 'Stonebridge Park'): 9134,
#  ('Stonebridge Park', 'Harlesden'): 10125,
#  ('Harlesden', 'Willesden Junction'): 11103,
#  ('Willesden Junction', 'Kensal Green'): 34845,
#  ('Willesden Junction', 'Acton Central'): 14290,
#  ('Willesden Junction', 'Kensal Rise'): 10540,
#  ('Willesden Junction', "Shepherd's Bush"): 25375,
#  ('Kensal Green', "Queen's Park"): 35572,
#  ("Queen's Park", 'Kilburn Park'): 4797,
#  ("Queen's Park", 'Kilburn High Road'): 38755,
#  ('Kilburn Park', 'Maida Vale'): 3214,
#  ('Maida Vale', 'Warwick Avenue'): 3859,
#  ('Cambridge Heath', 'Bethnal Green'): 12951,
#  ('Cambridge Heath', 'London Fields'): 13401,
#  ('London Fields', 'Hackney Downs'): 13373,
#  ('Hackney Downs', 'Rectory Road'): 3879,
#  ('Hackney Downs', 'Clapton'): 9950,
#  ('Rectory Road', 'Stoke Newington'): 3877,
#  ('Stoke Newington', 'Stamford Hill'): 3912,
#  ('Bruce Grove', 'White Hart Lane'): 11728,
#  ('White Hart Lane', 'Silver Street'): 10497,
#  ('Silver Street', 'Edmonton Green'): 8985,
#  ('Edmonton Green', 'Southbury'): 2937,
#  ('Edmonton Green', 'Bush Hill Park'): 4062,
#  ('Southbury', 'Turkey Street'): 2083,
#  ('Turkey Street', 'Theobalds Grove'): 934,
#  ('Theobalds Grove', 'Cheshunt'): 287,
#  ('Enfield Town', 'Bush Hill Park'): 2552,
#  ('Romford', 'Emerson Park'): 1184,
#  ('Romford', 'Chadwell Heath'): 14919,
#  ('Romford', 'Gidea Park'): 8884,
#  ('Clapton', 'St James Street'): 9539,
#  ('Wood Street', 'Highams Park'): 5510,
#  ('Highams Park', 'Chingford'): 2277,
#  ('South Acton', 'Acton Central'): 13546,
#  ('Kilburn High Road', 'South Hampstead'): 38834,
#  ('Kensal Rise', 'Brondesbury Park'): 9413,
#  ('Brondesbury Park', 'Brondesbury'): 9645,
#  ('Brondesbury', 'West Hampstead'): 9276,
#  ('West Hampstead', 'Finchley Road & Frognal'): 7134,
#  ('West Hampstead', 'Kilburn'): 11936,
#  ('Finchley Road & Frognal', 'Hampstead Heath'): 7135,
#  ('Hampstead Heath', 'Gospel Oak'): 6864,
#  ('Gospel Oak', 'Kentish Town West'): 5915,
#  ('Gospel Oak', 'Upper Holloway'): 1613,
#  ('Kentish Town West', 'Camden Road'): 4577,
#  ('Camden Road', 'Caledonian Road & Barnsbury'): 7516,
#  ('Canonbury', 'Dalston Kingsland'): 15683,
#  ('Canonbury', 'Dalston Junction'): 5701,
#  ('Dalston Kingsland', 'Hackney Central'): 14620,
#  ('Hackney Central', 'Homerton'): 12994,
#  ('Homerton', 'Hackney Wick'): 12321,
#  ('Hackney Wick', 'Stratford'): 11925,
#  ('Stratford', 'Leyton'): 56082,
#  ('Stratford', 'Maryland'): 34442,
#  ('Stratford', 'Stratford High Street'): 1484,
#  ('Stratford', 'Pudding Mill Lane'): 4711,
#  ('Stratford', 'Stratford International'): 3833,
#  ('Shadwell', 'Wapping'): 23181,
#  ('Shadwell', 'Limehouse'): 9646,
#  ('Shadwell', 'Tower Gateway'): 4195,
#  ('Wapping', 'Rotherhithe'): 23538,
#  ('Rotherhithe', 'Canada Water'): 23010,
#  ('Canada Water', 'Surrey Quays'): 36800,
#  ('Canada Water', 'Canary Wharf'): 75821,
#  ('Canada Water', 'Bermondsey'): 75398,
#  ('Surrey Quays', 'New Cross Gate'): 16779,
#  ('Surrey Quays', 'New Cross'): 2467,
#  ('Surrey Quays', 'Queens Road Peckham'): 14658,
#  ('New Cross Gate', 'Brockley'): 15071,
#  ('Shoreditch High Street', 'Hoxton'): 10621,
#  ('Sydenham', 'Crystal Palace'): 2434,
#  ('Sydenham', 'Forest Hill'): 9134,
#  ('Sydenham', 'Penge West'): 4981,
#  ('Queens Road Peckham', 'Peckham Rye'): 13367,
#  ('Peckham Rye', 'Denmark Hill'): 12864,
#  ('Denmark Hill', 'Clapham High Street'): 13232,
#  ('Clapham High Street', 'Wandsworth Road'): 12572,
#  ('Wandsworth Road', 'Clapham Junction'): 12007,
#  ('Wandsworth Road', 'Battersea Park'): 0,
#  ('Clapham Junction', 'Imperial Wharf'): 13977,
#  ('Bushey', 'Watford High Street'): 2871,
#  ('Bushey', 'Carpenders Park'): 3311,
#  ('Watford High Street', 'Watford Junction'): 1858,
#  ('Carpenders Park', 'Hatch End'): 3234,
#  ('Hatch End', 'Headstone Lane'): 3223,
#  ('Upper Holloway', 'Crouch Hill'): 2389,
#  ('Crouch Hill', 'Harringay Green Lanes'): 2593,
#  ('Harringay Green Lanes', 'South Tottenham'): 2916,
#  ('Walthamstow Queens Road', 'Leyton Midland Road'): 5649,
#  ('Leyton Midland Road', 'Leytonstone High Road'): 5330,
#  ('Leytonstone High Road', 'Wanstead Park'): 4754,
#  ('Wanstead Park', 'Woodgrange Park'): 3915,
#  ('Brockley', 'Honor Oak Park'): 12935,
#  ('Honor Oak Park', 'Forest Hill'): 11486,
#  ('Penge West', 'Anerley'): 4685,
#  ('Anerley', 'Norwood Junction'): 4259,
#  ('Norwood Junction', 'West Croydon'): 3380,
#  ('Dalston Junction', 'Haggerston'): 8144,
#  ('Haggerston', 'Hoxton'): 9063,
#  ("Shepherd's Bush", 'White City'): 31539,
#  ("Shepherd's Bush", 'Holland Park'): 11969,
#  ('South Ealing', 'Northfields'): 21492,
#  ('Knightsbridge', 'Hyde Park Corner'): 7061,
#  ('Covent Garden', 'Holborn'): 4804,
#  ('Holborn', 'Russell Square'): 21209,
#  ('Holborn', 'Chancery Lane'): 30016,
#  ('Caledonian Road', 'Holloway Road'): 5961,
#  ('Holloway Road', 'Arsenal'): 2814,
#  ('Manor House', 'Turnpike Lane'): 29359,
#  ('Turnpike Lane', 'Wood Green'): 22737,
#  ('Wood Green', 'Bounds Green'): 15448,
#  ('Bounds Green', 'Arnos Grove'): 10697,
#  ('Arnos Grove', 'Southgate'): 7501,
#  ('Southgate', 'Oakwood'): 3391,
#  ('Oakwood', 'Cockfosters'): 1262,
#  ('South Harrow', 'Sudbury Hill'): 5982,
#  ('Sudbury Hill', 'Sudbury Town'): 6272,
#  ('Sudbury Town', 'Alperton'): 6801,
#  ('Alperton', 'Park Royal'): 7712,
#  ('Park Royal', 'North Ealing'): 8501,
#  ('Heathrow Terminal 4', 'Hatton Cross'): 1194,
#  ('Heathrow Terminal 4', 'Heathrow Terminals 2 & 3'): 310,
#  ('Hatton Cross', 'Heathrow Terminals 2 & 3'): 5964,
#  ('Hatton Cross', 'Hounslow West'): 9260,
#  ('Heathrow Terminals 2 & 3', 'Heathrow Terminal 5'): 1913,
#  ('Hounslow West', 'Hounslow Central'): 11234,
#  ('Hounslow Central', 'Hounslow East'): 13469,
#  ('Hounslow East', 'Osterley'): 15935,
#  ('Osterley', 'Boston Manor'): 17445,
#  ('Boston Manor', 'Northfields'): 18598,
#  ('West Acton', 'North Acton'): 7352,
#  ('North Acton', 'Hanger Lane'): 14837,
#  ('North Acton', 'East Acton'): 24393,
#  ('West Ruislip', 'Ruislip Gardens'): 1277,
#  ('Ruislip Gardens', 'South Ruislip'): 2279,
#  ('South Ruislip', 'Northolt'): 3810,
#  ('Northolt', 'Greenford'): 7682,
#  ('Greenford', 'Perivale'): 10792,
#  ('Perivale', 'Hanger Lane'): 12330,
#  ('East Acton', 'White City'): 26064,
#  ('Queensway', 'Lancaster Gate'): 17636,
#  ('Lancaster Gate', 'Marble Arch'): 21904,
#  ('Marble Arch', 'Bond Street'): 26553,
#  ('Chancery Lane', "St. Paul's"): 31585,
#  ('Leyton', 'Leytonstone'): 48704,
#  ('Leytonstone', 'Snaresbrook'): 22990,
#  ('Leytonstone', 'Wanstead'): 19670,
#  ('Snaresbrook', 'South Woodford'): 21268,
#  ('South Woodford', 'Woodford'): 17198,
#  ('Woodford', 'Buckhurst Hill'): 10634,
#  ('Woodford', 'Roding Valley'): 2132,
#  ('Buckhurst Hill', 'Loughton'): 9118,
#  ('Loughton', 'Debden'): 6185,
#  ('Debden', 'Theydon Bois'): 4072,
#  ('Theydon Bois', 'Epping'): 3397,
#  ('Wanstead', 'Redbridge'): 17788,
#  ('Redbridge', 'Gants Hill'): 15670,
#  ('Gants Hill', 'Newbury Park'): 10086,
#  ('Newbury Park', 'Barkingside'): 5715,
#  ('Barkingside', 'Fairlop'): 4224,
#  ('Fairlop', 'Hainault'): 3129,
#  ('Hainault', 'Grange Hill'): 504,
#  ('Grange Hill', 'Chigwell'): 1184,
#  ('Chigwell', 'Roding Valley'): 1757,
#  ('Kingsbury', 'Queensbury'): 9419,
#  ('Queensbury', 'Canons Park'): 6385,
#  ('Canons Park', 'Stanmore'): 3624,
#  ('Canning Town', 'North Greenwich'): 31960,
#  ('Canning Town', 'Star Lane'): 452,
#  ('Canning Town', 'Royal Victoria'): 11357,
#  ('Canning Town', 'East India'): 4814,
#  ('Canning Town', 'West Silvertown'): 20147,
#  ('North Greenwich', 'Canary Wharf'): 29383,
#  ('Canary Wharf', 'West India Quay'): 7914,
#  ('Canary Wharf', 'Heron Quays'): 24482,
#  ("St. John's Wood", 'Swiss Cottage'): 3175,
#  ('Neasden', 'Dollis Hill'): 4019,
#  ('Dollis Hill', 'Willesden Green'): 1482,
#  ('Willesden Green', 'Kilburn'): 6029,
#  ('Maryland', 'Forest Gate'): 33938,
#  ('Forest Gate', 'Manor Park'): 31879,
#  ('Manor Park', 'Ilford'): 30542,
#  ('Ilford', 'Seven Kings'): 25313,
#  ('Seven Kings', 'Goodmayes'): 21970,
#  ('Goodmayes', 'Chadwell Heath'): 18594,
#  ('Gidea Park', 'Harold Wood'): 5522,
#  ('Harold Wood', 'Brentwood'): 2789,
#  ('Brentwood', 'Shenfield'): 1181,
#  ('Stratford High Street', 'Abbey Road'): 343,
#  ('Royal Victoria', 'Custom House'): 8797,
#  ('Limehouse', 'Westferry'): 10111,
#  ('Westferry', 'West India Quay'): 4910,
#  ('Westferry', 'Poplar'): 3780,
#  ('West India Quay', 'Poplar'): 2842,
#  ('Heron Quays', 'South Quay'): 25055,
#  ('South Quay', 'Crossharbour'): 21483,
#  ('Crossharbour', 'Mudchute'): 19821,
#  ('Mudchute', 'Island Gardens'): 18634,
#  ('Island Gardens', 'Cutty Sark'): 17428,
#  ('Cutty Sark', 'Greenwich'): 14480,
#  ('Greenwich', 'Deptford Bridge'): 13695,
#  ('Deptford Bridge', 'Elverson Road'): 11341,
#  ('Elverson Road', 'Lewisham'): 10268,
#  ('Poplar', 'All Saints'): 3739,
#  ('Poplar', 'Blackwall'): 3409,
#  ('All Saints', 'Langdon Park'): 3879,
#  ('Blackwall', 'East India'): 2582,
#  ('Custom House', 'Prince Regent'): 7305,
#  ('Prince Regent', 'Royal Albert'): 5759,
#  ('Royal Albert', 'Beckton Park'): 4511,
#  ('Beckton Park', 'Cyprus'): 4140,
#  ('Cyprus', 'Gallions Reach'): 2802,
#  ('Gallions Reach', 'Beckton'): 1621,
#  ('Langdon Park', 'Devons Road'): 4042,
#  ('Devons Road', 'Bow Church'): 4336,
#  ('Bow Church', 'Pudding Mill Lane'): 4070,
#  ('Woolwich Arsenal', 'King George V'): 12320,
#  ('King George V', 'London City Airport'): 13285,
#  ('West Silvertown', 'Pontoon Dock'): 18747,
#  ('Pontoon Dock', 'London City Airport'): 16218}

# %%
#set this as a network attribute
nx.set_edge_attributes(G, flows, 'flows')

# %%
#plot our calcuated flows
flows_values = flows.values()
flow_color=[(i[2]['flows']/max(flows_values)) for i in G.edges(data=True)]
flow_width=[(i[2]['flows']/max(flows_values)*10) for i in G.edges(data=True)]

# Plot graph
fig, ax = plt.subplots(figsize=(12,12))

#pos=nx.spring_layout(X)
edg=nx.draw_networkx_edges(G, pos,edge_color=flow_color, width=flow_width)

nx.draw_networkx_nodes(G,
        pos = pos,
        node_color= 'black',
        node_size= 1)

plt.colorbar(edg,label="Passenger Flows",orientation="horizontal", shrink=0.5)
plt.axis("off")
plt.title("London network Passenger Flows",fontsize=15)
plt.show()

# %%
#get edge with highest number of flows
max(flows, key=flows.get)
# Out:
# ('Bank and Monument', 'Waterloo')

# %% [markdown]
# What is going on here? Should we fix it or should we just consider it as a limitation of our model?
#
# **Bank-Waterloo seems intuitive!! Need to listen out in practical**

# %%
#get edge data with lowest number of flows
min(flows, key=flows.get)
# Out:
# ('Kennington', 'Nine Elms')

# %%
#save graph
for i in G.nodes():
    G.nodes[i]['coords'] = str(G.nodes[i]['coords'])
nx.write_graphml_lxml(G, "outputs/london_updated.graph")

# %% [markdown]
# **Create OD pairs with distance, population and jobs**
#
# Lastly for our spatial interaction we need to add distance data to our OD list, as well as population and jobs.
# Since we don't have population and jobs data at a station level, we will use total in and out flows as proxies.

# %%
#### Create Origin Destination matrix
OD = pd.pivot_table(london_OD_AMpeak, 
                    values ="flows", 
                    index="station_origin", 
                    columns = "station_destination",
                    aggfunc='sum', 
                    margins=True)
OD.fillna(0, inplace=True)
OD = OD.astype(int)
OD.to_csv('outputs/OD_matrix.csv')

# %%
OD.sort_values(by='All').tail(10)
# Out:
# station_destination       Abbey Road  Acton Central  Acton Town  Aldgate  \
# station_origin
# Finsbury Park                      0              0          19      156
# Canada Water                       0              0          17        0
# King's Cross St. Pancras           0              0          22      842
# Bank and Monument                  0              0           6       31
# Liverpool Street                   0              0          12      384
# London Bridge                      0              0          24       20
# Victoria                           0              0          30       59
# Stratford                        223             25           7       18
# Waterloo                           0              0          14      108
# All                              345            750        2202     7782
#
# station_destination       Aldgate East  All Saints  Alperton  Amersham  \
# station_origin
# Finsbury Park                       39           0         6         1
# Canada Water                         0           0         5         0
# King's Cross St. Pancras           160           0         7         2
# Bank and Monument                  250          25         0         0
# Liverpool Street                   150           0         3         3
# London Bridge                       47           0         9         1
# Victoria                           153           0         9         2
# Stratford                          186         157         3         0
# Waterloo                           381           0         6         1
# All                               7932         444       741       256
#
# station_destination       Anerley  Angel  ...  Wimbledon  Wimbledon Park  \
# station_origin                            ...
# Finsbury Park                   0     34  ...         16               4
# Canada Water                   43     81  ...          0               1
# King's Cross St. Pancras        0    135  ...         38               8
# Bank and Monument               0    518  ...         38               2
# Liverpool Street                0    121  ...          5               1
# London Bridge                   0    905  ...          0               1
# Victoria                        0    235  ...         53               2
# Stratford                       0    167  ...          3               4
# Waterloo                        0    306  ...          2               0
# All                           173   8103  ...       6295             596
#
# station_destination       Wood Green  Wood Lane  Wood Street  Woodford  \
# station_origin
# Finsbury Park                    113         18            0         0
# Canada Water                       6          2            0         3
# King's Cross St. Pancras          71        214            0         3
# Bank and Monument                 31          1            0        10
# Liverpool Street                  15         53           61        12
# London Bridge                     52          1            0         5
# Victoria                         122          2            0         7
# Stratford                         43          1            0       133
# Waterloo                          43          5            0        12
# All                             2146       1578          404       706
#
# station_destination       Woodgrange Park  Woodside Park  Woolwich Arsenal  \
# station_origin
# Finsbury Park                           0              2                 0
# Canada Water                            0              4                 0
# King's Cross St. Pancras                0             12                 0
# Bank and Monument                       0              9               509
# Liverpool Street                        0              1                 0
# London Bridge                           0              9                 0
# Victoria                                0             26                 0
# Stratford                               0              8              1106
# Waterloo                                0             18                 0
# All                                   242            745              4428
#
# station_destination           All
# station_origin
# Finsbury Park               24735
# Canada Water                27026
# King's Cross St. Pancras    28307
# Bank and Monument           29494
# Liverpool Street            31473
# London Bridge               32597
# Victoria                    37517
# Stratford                   59311
# Waterloo                    67372
# All                       1542391
#
# [10 rows x 400 columns]

# %%
#lets get total at origin and total at destinations
origin = OD.loc[:,'All'].to_dict()
destination = OD.loc['All',:].to_dict()

# %%
#lets add this data as population (origin - i.e. how many people are travelling FROM a station) and jobs (destination - i.e. how many people are travelling TO a station)
london_OD_AMpeak['population'] = london_OD_AMpeak.station_origin.apply(lambda x: origin[x])
london_OD_AMpeak['jobs'] = london_OD_AMpeak.station_destination.apply(lambda x: destination[x])

# %%
#get distance between stations withion the network
london_OD_AMpeak['distance'] = -1.0
for i, row in london_OD_AMpeak.iterrows():
    source = row.station_origin
    target = row.station_destination
    distance = nx.shortest_path_length(G, source, target, weight='length', method='dijkstra')
    london_OD_AMpeak.loc[i, 'distance'] = distance

# or you could use all_pairs_dijkstra_path_length(G, weight='length') to get all distances at once...

# %%
london_OD_AMpeak.to_csv('outputs/london_flows.csv', index=False)

# %% [markdown]
# There was some confusion about missing potential flows in the network for the assignment. This is how you would do the complete square matrix.

# %%
# remove the ALL column and row
OD_melt = OD.iloc[:-1,:-1]
# melt OD back to a long dataframe
OD_melt = OD_melt.reset_index().melt(id_vars='station_origin', value_vars=OD.columns[:-1])
OD_melt.columns = ['station_origin', 'station_destination', 'flows']
# remove the self flows
OD_melt = OD_melt[OD_melt.station_origin != OD_melt.station_destination]
OD_melt.head()
# Out:
#   station_origin station_destination  flows
# 1  Acton Central          Abbey Road      0
# 2     Acton Town          Abbey Road      0
# 3        Aldgate          Abbey Road      0
# 4   Aldgate East          Abbey Road      0
# 5     All Saints          Abbey Road      0

# %%
OD_melt['population'] = OD_melt.station_origin.apply(lambda x: origin[x])
OD_melt['jobs'] = OD_melt.station_destination.apply(lambda x: destination[x])

# %%
# get distance between stations withion the network
OD_melt['distance'] = -1.0
for i, row in OD_melt.iterrows():
    source = row.station_origin
    target = row.station_destination
    distance = nx.shortest_path_length(G, source, target, weight='length', method='dijkstra')
    OD_melt.loc[i, 'distance'] = distance

print(OD_melt.shape)
OD_melt.head()
# Out:
# (158802, 6)
#   station_origin station_destination  flows  population  jobs      distance
# 1  Acton Central          Abbey Road      0        1224   345  23424.039233
# 2     Acton Town          Abbey Road      0        3745   345  23638.269112
# 3        Aldgate          Abbey Road      0        2886   345   7888.874646
# 4   Aldgate East          Abbey Road      0        3172   345   6452.473345
# 5     All Saints          Abbey Road      0         740   345   5250.278454

# %%
OD_melt.sort_values('flows', ascending=False).head(20)
#misleading bc these locations don't have massive populations - they're just stations, so high input from other locations
# Out:
#            station_origin       station_destination  flows  population   jobs  \
# 6350             Waterloo         Bank and Monument  15946       67372  78549
# 22310            Waterloo              Canary Wharf   8085       67372  58772
# 85314           Stratford          Liverpool Street   6946       59311  61122
# 22159       London Bridge              Canary Wharf   6165       32597  58772
# 100904           Victoria             Oxford Circus   5181       37517  44368
# 21999        Canada Water              Canary Wharf   4030       27026  58772
# 22272           Stratford              Canary Wharf   3875       59311  58772
# 48093    Liverpool Street                Farringdon   3755       31473  25592
# 67156       Finsbury Park      Highbury & Islington   3659       24735  25385
# 85440        Canada Water             London Bridge   3202       27026  29930
# 130656             Ilford                 Stratford   3080        5298  55954
# 6040         Canary Wharf         Bank and Monument   2643       14632  78549
# 145193           Victoria             Warren Street   2599       37517  17309
# 100913           Waterloo             Oxford Circus   2425       67372  44368
# 100587            Brixton             Oxford Circus   2411       23381  44368
# 79126       Finsbury Park  King's Cross St. Pancras   2403       24735  33330
# 21960   Bank and Monument              Canary Wharf   2339       29494  58772
# 6197            Limehouse         Bank and Monument   2208        5348  78549
# 103706           Waterloo         Piccadilly Circus   2203       67372  13641
# 12734            Waterloo               Bond Street   2164       67372  20967
#
#            distance
# 6350    2542.900106
# 22310   7433.856719
# 85314   6698.344174
# 22159   5679.110688
# 100904  2220.118547
# 21999   2601.820450
# 22272   5482.583939
# 48093   1602.258638
# 67156   2057.320110
# 85440   3077.290238
# 130656  5635.382899
# 6040    5387.329623
# 145193  3369.804509
# 100913  2645.360656
# 100587  7538.840200
# 79126   4089.402778
# 21960   5387.329623
# 6197    3509.541552
# 103706  1681.545497
# 12734   3199.690941

# %%
# plot flows against distance, both in the log scale
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(OD_melt.distance, OD_melt.flows, alpha=0.5)
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlabel('Distance (m)')
ax.set_ylabel('Flows')
ax.set_title('Flows vs Distance')

plt.show()

# %% [markdown]
# # exercise

# %% [markdown]
# #### Part A
# Let's calculate the flows between 2 stations in the network by combing origin-destinction data with topogical data.
#
# + Get the flows between 2 stations that are separated by a single station (a --> b --> c) on the network
# + Find a way to separate out the flows between a and c from those between a and b and b and c

# %%
#Focusing on stations from quiz:

origin = 'Uxbridge'
destination = 'Ickenham'

# Get shortest path
shortest_path_stations = nx.shortest_path(G, source=origin, target=destination, weight="length", method="dijkstra")

# Print results
print(f"Shortest path from {origin} to {destination}: {shortest_path_stations}")
# Out:
# Shortest path from Uxbridge to Ickenham: ['Uxbridge', 'Hillingdon', 'Ickenham']

# %%
#Get direct flows from Uxbridge to Ickenham
london_OD_AMpeak[
    (london_OD_AMpeak['station_origin'] == origin) & 
    (london_OD_AMpeak['station_destination'] == destination)]
# Out:
#       station_origin station_destination  flows  population  jobs     distance
# 54307       Uxbridge            Ickenham    104        2764   282  3268.833515

# %%
#Get direct flows from Uxbridge to Hillingdon
middle = 'Hillingdon'
london_OD_AMpeak[
    (london_OD_AMpeak['station_origin'] == origin) & 
    (london_OD_AMpeak['station_destination'] == middle)]
# Out:
#       station_origin station_destination  flows  population  jobs    distance
# 54299       Uxbridge          Hillingdon     62        2764   318  2144.40293

# %%
#Get direct flows from Hillingdon to Ickenham
london_OD_AMpeak[
    (london_OD_AMpeak['station_origin'] == middle) & 
    (london_OD_AMpeak['station_destination'] == destination)]
# Out:
#       station_origin station_destination  flows  population  jobs     distance
# 25794     Hillingdon            Ickenham     11        1337   282  1124.430585

# %% [markdown]
# #### Part B
# What are the limitations of this undirected network? Let's go back and think about a directed network.

# %% [markdown]
# What are some questions that you can ask with this directed network that you can't with the undirected network?
#
# + Let's call a station's "directionality" the difference between the number of people going through a station in one direction and the other.
# + Which stations have the highest directionality?
# + What about the lowest?

# %%
# recreate our network but with directional Graph by specifying create_using parameter!
G_di = nx.from_pandas_edgelist(edge_gdf, source = 'start_id', target='end_id', edge_attr=['length', 'line_name'], create_using=nx.DiGraph)

# we need to add an extra step to iterate through the edges from the opposite direction 
for i, edge in edge_gdf.iterrows():
    if not G_di.has_edge(edge['end_id'], edge['start_id']):
        G_di.add_edge(edge['end_id'], edge['start_id'], length=edge['length'], line_name=edge['line_name'])

# adding the position of the nodes
pos = {row['name']: row.geometry.coords[0] for i, row in stations.iterrows() if row['name'] in G_di.nodes()}
nx.set_node_attributes(G_di, pos, 'coords')

# %%
#Add flows (see code above)

#create a dictionary to store flows for all edges
flows = {(u,v): 0 for u,v in G_di.edges()}
#This is adding the number of flows for each OD journey to all of the edges on the shortest path

#calculate shortest paths for all flows and add data to dict
for i, row in london_OD_AMpeak.iterrows():
    source = row.station_origin
    target = row.station_destination
    
    #get shortest path
    path = nx.dijkstra_path(G_di, source, target)
    
    #our path is a list of nodes, we need to turn this to a list of edges
    path_edges = list(zip(path,path[1:])) 
    
    #add flows to our dict
    for u,v in path_edges:
        try:
            flows[(u,v)] += row.flows
        except:
            flows[(v,u)] += row.flows

#set this as a network attribute
nx.set_edge_attributes(G_di, flows, 'flows')

# %%
#Calculate directionality
directionality = {node: G_di.in_degree(node, weight='flows') - G_di.out_degree(node, weight='flows') for node in G_di.nodes()}
highest_directionality = sorted(directionality.items(), key=lambda x: x[1], reverse=True)[:10]
lowest_directionality = sorted(directionality.items(), key=lambda x: x[1])[:10]

print('Highest directionality stations (more come in than leave in peak AM period):')
highest_directionality
# Out:
# Highest directionality stations (more come in than leave in peak AM period):
# [('Bank and Monument', 49055),
#  ('Canary Wharf', 44140),
#  ('Oxford Circus', 41584),
#  ('Liverpool Street', 29649),
#  ('Green Park', 24688),
#  ('Holborn', 20684),
#  ('Farringdon', 20540),
#  ('Moorgate', 20158),
#  ('Bond Street', 18929),
#  ('Tottenham Court Road', 17353)]

# %%
print('Lowest directionality stations (more leave than come in peak AM period):')
lowest_directionality
# Out:
# Lowest directionality stations (more leave than come in peak AM period):
# [('Waterloo', -43906),
#  ('Brixton', -18297),
#  ('Finsbury Park', -17966),
#  ('Walthamstow Central', -12228),
#  ('Stockwell', -9044),
#  ('Seven Sisters', -8589),
#  ('Ealing Broadway', -8007),
#  ('Morden', -6588),
#  ('Canada Water', -6583),
#  ('Leyton', -6204)]

# %% [markdown]
# #### Part C
# Further Exploration Over the data, try to explore PM peak time band for further understanding of the directionality of the system.

# %%
#Timeband 5 is peak

#rename column
london_OD_PMpeak = london_OD[['station_origin', 'station_destination', '5']].copy()
london_OD_PMpeak.rename({'5':'flows'}, axis=1, inplace=True)

#since the flows are averages the are stored as floats.
#for our analysis we will turn the into ints
london_OD_PMpeak.flows = london_OD_PMpeak.flows.astype(int)
london_OD_PMpeak.head()
# Out:
#                 station_origin  station_destination  flows
# 0  Stratford International DLR        King George V     28
# 1  Stratford International DLR  London City Airport     57
# 2  Stratford International DLR         Pontoon Dock     43
# 3  Stratford International DLR      West Silvertown     24
# 4  Stratford International DLR     Woolwich Arsenal    387

# %%
london_OD_PMpeak['station_origin']= london_OD_PMpeak.station_origin.apply(lambda x: 
                                      re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)
                                     )
london_OD_PMpeak['station_destination']=london_OD_PMpeak.station_destination.apply(lambda x: 
                                      re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)
                                     )
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jessi\AppData\Local\Temp\ipykernel_44796\3041545488.py:2: SyntaxWarning: invalid escape sequence '\s'
#   re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)
# C:\Users\jessi\AppData\Local\Temp\ipykernel_44796\3041545488.py:5: SyntaxWarning: invalid escape sequence '\s'
#   re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)

# %%
london_OD_PMpeak = london_OD_PMpeak.groupby(['station_origin', 'station_destination'], as_index=False).sum()

# %%
highest_outflow = london_OD_PMpeak.groupby('station_origin', observed=True).agg(total_outflow=('flows', 'sum')).reset_index().sort_values(by='total_outflow', ascending=[False])

highest_outflow
# Out:
#         station_origin  total_outflow
# 16   Bank and Monument          74229
# 218   Liverpool Street          60018
# 333          Stratford          58944
# 56        Canary Wharf          47950
# 257      Oxford Circus          41911
# ..                 ...            ...
# 115       Emerson Park             82
# 138        Grange Hill             79
# 24        Beckton Park             76
# 285      Roding Valley             43
# 21      Battersea Park              0
#
# [406 rows x 2 columns]
